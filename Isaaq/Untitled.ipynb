# %%
import requests

url = "https://api-football-beta.p.rapidapi.com/standings"

querystring = {"season":"2022","league":"39"}

headers = {
	"X-RapidAPI-Key": "b7cf950dddmsh7909c2d31444039p1a7716jsnaed17a1b9be9",
	"X-RapidAPI-Host": "api-football-beta.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(type(response.json()))
print(response.json())
hj = response.json()
# Out:
# <class 'dict'>
# {'get': 'standings', 'parameters': {'league': '39', 'season': '2022'}, 'errors': [], 'results': 1, 'paging': {'current': 1, 'total': 1}, 'response': [{'league': {'id': 39, 'name': 'Premier League', 'country': 'England', 'logo': 'https://media.api-sports.io/football/leagues/39.png', 'flag': 'https://media.api-sports.io/flags/gb.svg', 'season': 2022, 'standings': [[{'rank': 1, 'team': {'id': 42, 'name': 'Arsenal', 'logo': 'https://media.api-sports.io/football/teams/42.png'}, 'points': 37, 'goalsDiff': 22, 'group': 'Premier League', 'form': 'WWWDW', 'status': 'same', 'description': 'Promotion - Champions League (Group Stage)', 'all': {'played': 14, 'win': 12, 'draw': 1, 'lose': 1, 'goals': {'for': 33, 'against': 11}}, 'home': {'played': 6, 'win': 6, 'draw': 0, 'lose': 0, 'goals': {'for': 19, 'against': 7}}, 'away': {'played': 8, 'win': 6, 'draw': 1, 'lose': 1, 'goals': {'for': 14, 'against': 4}}, 'update': '2022-11-13T00:00:00+00:00'}, {'rank': 2, 'team': {'id': 50, 'name': 'Manchester City', 'logo': 'https://media.api-sports.io/football/teams/50.png'}, 'points': 32, 'goalsDiff': 26, 'group': 'Premier League', 'form': 'LWWWL', 'status': 'same', 'description': 'Promotion - Champions League (Group Stage)', 'all': {'played': 14, 'win': 10, 'draw': 2, 'lose': 2, 'goals': {'for': 40, 'against': 14}}, 'home': {'played': 8, 'win': 7, 'draw': 0, 'lose': 1, 'goals': {'for': 30, 'against': 9}}, 'away': {'played': 6, 'win': 3, 'draw': 2, 'lose': 1, 'goals': {'for': 10, 'against': 5}}, 'update': '2022-11-13T00:00:00+00:00'}, {'rank': 3, 'team': {'id': 34, 'name': 'Newcastle', 'logo': 'https://media.api-sports.io/football/teams/34.png'}, 'points': 30, 'goalsDiff': 18, 'group': 'Premier League', 'form': 'WWWWW', 'status': 'same', 'description': 'Promotion - Champions League (Group Stage)', 'all': {'played': 15, 'win': 8, 'draw': 6, 'lose': 1, 'goals': {'for': 29, 'against': 11}}, 'home': {'played': 8, 'win': 5, 'draw': 3, 'lose': 0, 'goals': {'for': 17, 'against': 5}}, 'away': {'played': 7, 'win': 3, 'draw': 3, 'lose': 1, 'goals': {'for': 12, 'against': 6}}, 'update': '2022-11-13T00:00:00+00:00'}, {'rank': 4, 'team': {'id': 47, 'name': 'Tottenham', 'logo': 'https://media.api-sports.io/football/teams/47.png'}, 'points': 29, 'goalsDiff': 10, 'group': 'Premier League', 'form': 'WLWLL', 'status': 'same', 'description': 'Promotion - Champions League (Group Stage)', 'all': {'played': 15, 'win': 9, 'draw': 2, 'lose': 4, 'goals': {'for': 31, 'against': 21}}, 'home': {'played': 8, 'win': 6, 'draw': 0, 'lose': 2, 'goals': {'for': 21, 'against': 11}}, 'away': {'played': 7, 'win': 3, 'draw': 2, 'lose': 2, 'goals': {'for': 10, 'against': 10}}, 'update': '2022-11-13T00:00:00+00:00'}, {'rank': 5, 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media.api-sports.io/football/teams/33.png'}, 'points': 26, 'goalsDiff': 0, 'group': 'Premier League', 'form': 'WLWDW', 'status': 'same', 'description': 'Promotion - Europa League (Group Stage)', 'all': {'played': 14, 'win': 8, 'draw': 2, 'lose': 4, 'goals': {'for': 20, 'against': 20}}, 'home': {'played': 6, 'win': 4, 'draw': 1, 'lose': 1, 'goals': {'for': 9, 'against': 4}}, 'away': {'played': 8, 'win': 4, 'draw': 1, 'lose': 3, 'goals': {'for': 11, 'against': 16}}, 'update': '2022-11-13T00:00:00+00:00'}, {'rank': 6, 'team': {'id': 40, 'name': 'Liverpool', 'logo': 'https://media.api-sports.io/football/teams/40.png'}, 'points': 22, 'goalsDiff': 11, 'group': 'Premier League', 'form': 'WWLLW', 'status': 'same', 'description': None, 'all': {'played': 14, 'win': 6, 'draw': 4, 'lose': 4, 'goals': {'for': 28, 'against': 17}}, 'home': {'played': 8, 'win': 5, 'draw': 2, 'lose': 1, 'goals': {'for': 21, 'against': 8}}, 'away': {'played': 6, 'win': 1, 'draw': 2, 'lose': 3, 'goals': {'for': 7, 'against': 9}}, 'update': '2022-11-13T00:00:00+00:00'}, {'rank': 7, 'team': {'id': 51, 'name': 'Brighton', 'logo': 'https://media.api-sports.io/football/teams/51.png'}, 'points': 21, 'goalsDiff': 4, 'group': 'Premier League', ' ...

# %%
hj['response']
# Out:
# [{'league': {'id': 39,
#    'name': 'Premier League',
#    'country': 'England',
#    'logo': 'https://media.api-sports.io/football/leagues/39.png',
#    'flag': 'https://media.api-sports.io/flags/gb.svg',
#    'season': 2022,
#    'standings': [[{'rank': 1,
#       'team': {'id': 42,
#        'name': 'Arsenal',
#        'logo': 'https://media.api-sports.io/football/teams/42.png'},
#       'points': 37,
#       'goalsDiff': 22,
#       'group': 'Premier League',
#       'form': 'WWWDW',
#       'status': 'same',
#       'description': 'Promotion - Champions League (Group Stage)',
#       'all': {'played': 14,
#        'win': 12,
#        'draw': 1,
#        'lose': 1,
#        'goals': {'for': 33, 'against': 11}},
#       'home': {'played': 6,
#        'win': 6,
#        'draw': 0,
#        'lose': 0,
#        'goals': {'for': 19, 'against': 7}},
#       'away': {'played': 8,
#        'win': 6,
#        'draw': 1,
#        'lose': 1,
#        'goals': {'for': 14, 'against': 4}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 2,
#       'team': {'id': 50,
#        'name': 'Manchester City',
#        'logo': 'https://media.api-sports.io/football/teams/50.png'},
#       'points': 32,
#       'goalsDiff': 26,
#       'group': 'Premier League',
#       'form': 'LWWWL',
#       'status': 'same',
#       'description': 'Promotion - Champions League (Group Stage)',
#       'all': {'played': 14,
#        'win': 10,
#        'draw': 2,
#        'lose': 2,
#        'goals': {'for': 40, 'against': 14}},
#       'home': {'played': 8,
#        'win': 7,
#        'draw': 0,
#        'lose': 1,
#        'goals': {'for': 30, 'against': 9}},
#       'away': {'played': 6,
#        'win': 3,
#        'draw': 2,
#        'lose': 1,
#        'goals': {'for': 10, 'against': 5}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 3,
#       'team': {'id': 34,
#        'name': 'Newcastle',
#        'logo': 'https://media.api-sports.io/football/teams/34.png'},
#       'points': 30,
#       'goalsDiff': 18,
#       'group': 'Premier League',
#       'form': 'WWWWW',
#       'status': 'same',
#       'description': 'Promotion - Champions League (Group Stage)',
#       'all': {'played': 15,
#        'win': 8,
#        'draw': 6,
#        'lose': 1,
#        'goals': {'for': 29, 'against': 11}},
#       'home': {'played': 8,
#        'win': 5,
#        'draw': 3,
#        'lose': 0,
#        'goals': {'for': 17, 'against': 5}},
#       'away': {'played': 7,
#        'win': 3,
#        'draw': 3,
#        'lose': 1,
#        'goals': {'for': 12, 'against': 6}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 4,
#       'team': {'id': 47,
#        'name': 'Tottenham',
#        'logo': 'https://media.api-sports.io/football/teams/47.png'},
#       'points': 29,
#       'goalsDiff': 10,
#       'group': 'Premier League',
#       'form': 'WLWLL',
#       'status': 'same',
#       'description': 'Promotion - Champions League (Group Stage)',
#       'all': {'played': 15,
#        'win': 9,
#        'draw': 2,
#        'lose': 4,
#        'goals': {'for': 31, 'against': 21}},
#       'home': {'played': 8,
#        'win': 6,
#        'draw': 0,
#        'lose': 2,
#        'goals': {'for': 21, 'against': 11}},
#       'away': {'played': 7,
#        'win': 3,
#        'draw': 2,
#        'lose': 2,
#        'goals': {'for': 10, 'against': 10}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 5,
#       'team': {'id': 33,
#        'name': 'Manchester United',
#        'logo': 'https://media.api-sports.io/football/teams/33.png'},
#       'points': 26,
#       'goalsDiff': 0,
#       'group': 'Premier League',
#       'form': 'WLWDW',
#       'status': 'same',
#       'description': 'Promotion - Europa League (Group Stage)',
#       'all': {'played': 14,
#        'win': 8,
#        'draw': 2,
#        'lose': 4,
#        'goals': {'for': 20, 'against': 20}},
#       'home': {'played': 6,
#        'win': 4,
#        'draw': 1,
#        'lose': 1,
#        'goals': {'for': 9, 'against': 4}},
#       'away': {'played': 8,
#        'win': 4,
#        'draw': 1,
#        'lose': 3,
#        'goals': {'for': 11, 'against': 16}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 6,
#       'team': {'id': 40,
#        'name': 'Liverpool',
#        'logo': 'https://media.api-sports.io/football/teams/40.png'},
#       'points': 22,
#       'goalsDiff': 11,
#       'group': 'Premier League',
#       'form': 'WWLLW',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 14,
#        'win': 6,
#        'draw': 4,
#        'lose': 4,
#        'goals': {'for': 28, 'against': 17}},
#       'home': {'played': 8,
#        'win': 5,
#        'draw': 2,
#        'lose': 1,
#        'goals': {'for': 21, 'against': 8}},
#       'away': {'played': 6,
#        'win': 1,
#        'draw': 2,
#        'lose': 3,
#        'goals': {'for': 7, 'against': 9}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 7,
#       'team': {'id': 51,
#        'name': 'Brighton',
#        'logo': 'https://media.api-sports.io/football/teams/51.png'},
#       'points': 21,
#       'goalsDiff': 4,
#       'group': 'Premier League',
#       'form': 'LWWLD',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 14,
#        'win': 6,
#        'draw': 3,
#        'lose': 5,
#        'goals': {'for': 23, 'against': 19}},
#       'home': {'played': 7,
#        'win': 3,
#        'draw': 2,
#        'lose': 2,
#        'goals': {'for': 11, 'against': 6}},
#       'away': {'played': 7,
#        'win': 3,
#        'draw': 1,
#        'lose': 3,
#        'goals': {'for': 12, 'against': 13}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 8,
#       'team': {'id': 49,
#        'name': 'Chelsea',
#        'logo': 'https://media.api-sports.io/football/teams/49.png'},
#       'points': 21,
#       'goalsDiff': 0,
#       'group': 'Premier League',
#       'form': 'LLLDD',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 14,
#        'win': 6,
#        'draw': 3,
#        'lose': 5,
#        'goals': {'for': 17, 'against': 17}},
#       'home': {'played': 6,
#        'win': 3,
#        'draw': 2,
#        'lose': 1,
#        'goals': {'for': 10, 'against': 6}},
#       'away': {'played': 8,
#        'win': 3,
#        'draw': 1,
#        'lose': 4,
#        'goals': {'for': 7, 'against': 11}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 9,
#       'team': {'id': 36,
#        'name': 'Fulham',
#        'logo': 'https://media.api-sports.io/football/teams/36.png'},
#       'points': 19,
#       'goalsDiff': -2,
#       'group': 'Premier League',
#       'form': 'LLDWW',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 15,
#        'win': 5,
#        'draw': 4,
#        'lose': 6,
#        'goals': {'for': 24, 'against': 26}},
#       'home': {'played': 8,
#        'win': 3,
#        'draw': 3,
#        'lose': 2,
#        'goals': {'for': 14, 'against': 13}},
#       'away': {'played': 7,
#        'win': 2,
#        'draw': 1,
#        'lose': 4,
#        'goals': {'for': 10, 'against': 13}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 10,
#       'team': {'id': 55,
#        'name': 'Brentford',
#        'logo': 'https://media.api-sports.io/football/teams/55.png'},
#       'points': 19,
#       'goalsDiff': -2,
#       'group': 'Premier League',
#       'form': 'WDDLD',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 15,
#        'win': 4,
#        'draw': 7,
#        'lose': 4,
#        'goals': {'for': 23, 'against': 25}},
#       'home': {'played': 7,
#        'win': 3,
#        'draw': 3,
#        'lose': 1,
#        'goals': {'for': 13, 'against': 7}},
#       'away': {'played': 8,
#        'win': 1,
#        'draw': 4,
#        'lose': 3,
#        'goals': {'for': 10, 'against': 18}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 11,
#       'team': {'id': 52,
#        'name': 'Crystal Palace',
#        'logo': 'https://media.api-sports.io/football/teams/52.png'},
#       'points': 19,
#       'goalsDiff': -3,
#       'group': 'Premier League',
#       'form': 'LWWLW',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 14,
#        'win': 5,
#        'draw': 4,
#        'lose': 5,
#        'goals': {'for': 15, 'against': 18}},
#       'home': {'played': 7,
#        'win': 4,
#        'draw': 1,
#        'lose': 2,
#        'goals': {'for': 10, 'against': 8}},
#       'away': {'played': 7,
#        'win': 1,
#        'draw': 3,
#        'lose': 3,
#        'goals': {'for': 5, 'against': 10}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 12,
#       'team': {'id': 66,
#        'name': 'Aston Villa',
#        'logo': 'https://media.api-sports.io/football/teams/66.png'},
#       'points': 18,
#       'goalsDiff': -6,
#       'group': 'Premier League',
#       'form': 'WWLWL',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 15,
#        'win': 5,
#        'draw': 3,
#        'lose': 7,
#        'goals': {'for': 16, 'against': 22}},
#       'home': {'played': 7,
#        'win': 4,
#        'draw': 1,
#        'lose': 2,
#        'goals': {'for': 11, 'against': 6}},
#       'away': {'played': 8,
#        'win': 1,
#        'draw': 2,
#        'lose': 5,
#        'goals': {'for': 5, 'against': 16}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 13,
#       'team': {'id': 46,
#        'name': 'Leicester',
#        'logo': 'https://media.api-sports.io/football/teams/46.png'},
#       'points': 17,
#       'goalsDiff': 0,
#       'group': 'Premier League',
#       'form': 'WWLWW',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 15,
#        'win': 5,
#        'draw': 2,
#        'lose': 8,
#        'goals': {'for': 25, 'against': 25}},
#       'home': {'played': 7,
#        'win': 2,
#        'draw': 2,
#        'lose': 3,
#        'goals': {'for': 9, 'against': 6}},
#       'away': {'played': 8,
#        'win': 3,
#        'draw': 0,
#        'lose': 5,
#        'goals': {'for': 16, 'against': 19}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 14,
#       'team': {'id': 35,
#        'name': 'Bournemouth',
#        'logo': 'https://media.api-sports.io/football/teams/35.png'},
#       'points': 16,
#       'goalsDiff': -14,
#       'group': 'Premier League',
#       'form': 'WLLLL',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 15,
#        'win': 4,
#        'draw': 4,
#        'lose': 7,
#        'goals': {'for': 18, 'against': 32}},
#       'home': {'played': 8,
#        'win': 3,
#        'draw': 2,
#        'lose': 3,
#        'goals': {'for': 9, 'against': 8}},
#       'away': {'played': 7,
#        'win': 1,
#        'draw': 2,
#        'lose': 4,
#        'goals': {'for': 9, 'against': 24}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 15,
#       'team': {'id': 63,
#        'name': 'Leeds',
#        'logo': 'https://media.api-sports.io/football/teams/63.png'},
#       'points': 15,
#       'goalsDiff': -4,
#       'group': 'Premier League',
#       'form': 'LWWLL',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 14,
#        'win': 4,
#        'draw': 3,
#        'lose': 7,
#        'goals': {'for': 22, 'against': 26}},
#       'home': {'played': 7,
#        'win': 3,
#        'draw': 2,
#        'lose': 2,
#        'goals': {'for': 12, 'against': 9}},
#       'away': {'played': 7,
#        'win': 1,
#        'draw': 1,
#        'lose': 5,
#        'goals': {'for': 10, 'against': 17}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 16,
#       'team': {'id': 48,
#        'name': 'West Ham',
#        'logo': 'https://media.api-sports.io/football/teams/48.png'},
#       'points': 14,
#       'goalsDiff': -5,
#       'group': 'Premier League',
#       'form': 'LLLWL',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 15,
#        'win': 4,
#        'draw': 2,
#        'lose': 9,
#        'goals': {'for': 12, 'against': 17}},
#       'home': {'played': 8,
#        'win': 3,
#        'draw': 1,
#        'lose': 4,
#        'goals': {'for': 9, 'against': 10}},
#       'away': {'played': 7,
#        'win': 1,
#        'draw': 1,
#        'lose': 5,
#        'goals': {'for': 3, 'against': 7}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 17,
#       'team': {'id': 45,
#        'name': 'Everton',
#        'logo': 'https://media.api-sports.io/football/teams/45.png'},
#       'points': 14,
#       'goalsDiff': -6,
#       'group': 'Premier League',
#       'form': 'LLDWL',
#       'status': 'same',
#       'description': None,
#       'all': {'played': 15,
#        'win': 3,
#        'draw': 5,
#        'lose': 7,
#        'goals': {'for': 11, 'against': 17}},
#       'home': {'played': 7,
#        'win': 2,
#        'draw': 2,
#        'lose': 3,
#        'goals': {'for': 6, 'against': 6}},
#       'away': {'played': 8,
#        'win': 1,
#        'draw': 3,
#        'lose': 4,
#        'goals': {'for': 5, 'against': 11}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 18,
#       'team': {'id': 65,
#        'name': 'Nottingham Forest',
#        'logo': 'https://media.api-sports.io/football/teams/65.png'},
#       'points': 13,
#       'goalsDiff': -19,
#       'group': 'Premier League',
#       'form': 'WDLWD',
#       'status': 'same',
#       'description': 'Relegation - Championship',
#       'all': {'played': 15,
#        'win': 3,
#        'draw': 4,
#        'lose': 8,
#        'goals': {'for': 11, 'against': 30}},
#       'home': {'played': 8,
#        'win': 3,
#        'draw': 2,
#        'lose': 3,
#        'goals': {'for': 10, 'against': 11}},
#       'away': {'played': 7,
#        'win': 0,
#        'draw': 2,
#        'lose': 5,
#        'goals': {'for': 1, 'against': 19}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 19,
#       'team': {'id': 41,
#        'name': 'Southampton',
#        'logo': 'https://media.api-sports.io/football/teams/41.png'},
#       'points': 12,
#       'goalsDiff': -14,
#       'group': 'Premier League',
#       'form': 'LLLDW',
#       'status': 'same',
#       'description': 'Relegation - Championship',
#       'all': {'played': 15,
#        'win': 3,
#        'draw': 3,
#        'lose': 9,
#        'goals': {'for': 13, 'against': 27}},
#       'home': {'played': 7,
#        'win': 1,
#        'draw': 3,
#        'lose': 3,
#        'goals': {'for': 8, 'against': 12}},
#       'away': {'played': 8,
#        'win': 2,
#        'draw': 0,
#        'lose': 6,
#        'goals': {'for': 5, 'against': 15}},
#       'update': '2022-11-13T00:00:00+00:00'},
#      {'rank': 20,
#       'team': {'id': 39,
#        'name': 'Wolves',
#        'logo': 'https://media.api-sports.io/football/teams/39.png'},
#       'points': 10,
#       'goalsDiff': -16,
#       'group': 'Premier League',
#       'form': 'LLDLL',
#       'status': 'same',
#       'description': 'Relegation - Championship',
#       'all': {'played': 15,
#        'win': 2,
#        'draw': 4,
#        'lose': 9,
#        'goals': {'for': 8, 'against': 24}},
#       'home': {'played': 8,
#        'win': 2,
#        'draw': 2,
#        'lose': 4,
#        'goals': {'for': 5, 'against': 13}},
#       'away': {'played': 7,
#        'win': 0,
#        'draw': 2,
#        'lose': 5,
#        'goals': {'for': 3, 'against': 11}},
#       'update': '2022-11-13T00:00:00+00:00'}]]}}]

# %%
 hj['response'][0]['league']['standings'][0][0]['team']
# Out:
# {'id': 42,
#  'name': 'Arsenal',
#  'logo': 'https://media.api-sports.io/football/teams/42.png'}

# %%
a = str(hj['response'][0]['league']['standings'][0][0]['team']['name'])
b = str(hj['response'][0]['league']['standings'][0][0]['form'])
c=  str(hj['response'][0]['league']['standings'][0][0]['description'])
d = str(hj['response'][0]['league']['standings'][0][0]['points'])
q=input("what would you like to know?")
standings = [a,b,c]
for standing in standings:
    while True:
        if q == 'top':
            print(a)
            break
        elif q == 'form':
            print('form ' + b)
            break
        else:
            print('Invalid Request')
            break
l=input('would you like to know their current points?')
if l == 'yes':
    print(d)
else:
    print("Okay that's fine!")
# Out:
# what would you like to know?j
# Invalid Request
# Invalid Request
# Invalid Request
# would you like to know their current points?d
# Okay that's fine!

# %%
hl = "ten hag"

# %%
import requests

url = "https://api-football-beta.p.rapidapi.com/coachs"

querystring = {"search":hl}

headers = {
	"X-RapidAPI-Key": "b7cf950dddmsh7909c2d31444039p1a7716jsnaed17a1b9be9",
	"X-RapidAPI-Host": "api-football-beta.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
print(type(response.json()))
print(response.json())
aa = response.json()
# Out:
# {"get":"coachs","parameters":{"search":"ten hag"},"errors":[],"results":1,"paging":{"current":1,"total":1},"response":[{"id":1993,"name":"E. ten Hag","firstname":"Erik","lastname":"ten Hag","age":52,"birth":{"date":"1970-02-02","place":"Haaksbergen","country":"Netherlands"},"nationality":"Netherlands","height":null,"weight":null,"photo":"https:\/\/media.api-sports.io\/football\/coachs\/1993.png","team":{"id":33,"name":"Manchester United","logo":"https:\/\/media.api-sports.io\/football\/teams\/33.png"},"career":[{"team":{"id":33,"name":"Manchester United","logo":"https:\/\/media.api-sports.io\/football\/teams\/33.png"},"start":"2022-06-01","end":null},{"team":{"id":194,"name":"Ajax","logo":"https:\/\/media.api-sports.io\/football\/teams\/194.png"},"start":"2018-01-01","end":"2022-05-01"},{"team":{"id":207,"name":"Utrecht","logo":"https:\/\/media.api-sports.io\/football\/teams\/207.png"},"start":"2015-07-01","end":"2017-12-01"},{"team":{"id":4674,"name":"Bayern M\u00fcnchen II","logo":"https:\/\/media.api-sports.io\/football\/teams\/4674.png"},"start":"2013-06-01","end":"2015-07-01"},{"team":{"id":410,"name":"Go Ahead Eagles","logo":"https:\/\/media.api-sports.io\/football\/teams\/410.png"},"start":"2012-07-01","end":"2013-06-01"}]}]}
# <class 'dict'>
# {'get': 'coachs', 'parameters': {'search': 'ten hag'}, 'errors': [], 'results': 1, 'paging': {'current': 1, 'total': 1}, 'response': [{'id': 1993, 'name': 'E. ten Hag', 'firstname': 'Erik', 'lastname': 'ten Hag', 'age': 52, 'birth': {'date': '1970-02-02', 'place': 'Haaksbergen', 'country': 'Netherlands'}, 'nationality': 'Netherlands', 'height': None, 'weight': None, 'photo': 'https://media.api-sports.io/football/coachs/1993.png', 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media.api-sports.io/football/teams/33.png'}, 'career': [{'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media.api-sports.io/football/teams/33.png'}, 'start': '2022-06-01', 'end': None}, {'team': {'id': 194, 'name': 'Ajax', 'logo': 'https://media.api-sports.io/football/teams/194.png'}, 'start': '2018-01-01', 'end': '2022-05-01'}, {'team': {'id': 207, 'name': 'Utrecht', 'logo': 'https://media.api-sports.io/football/teams/207.png'}, 'start': '2015-07-01', 'end': '2017-12-01'}, {'team': {'id': 4674, 'name': 'Bayern München II', 'logo': 'https://media.api-sports.io/football/teams/4674.png'}, 'start': '2013-06-01', 'end': '2015-07-01'}, {'team': {'id': 410, 'name': 'Go Ahead Eagles', 'logo': 'https://media.api-sports.io/football/teams/410.png'}, 'start': '2012-07-01', 'end': '2013-06-01'}]}]}

# %%
aa['response']
# Out:
# [{'id': 40,
#   'name': 'T. Tuchel',
#   'firstname': 'Thomas',
#   'lastname': 'Tuchel',
#   'age': 49,
#   'birth': {'date': '1973-08-29', 'place': 'Krumbach', 'country': 'Germany'},
#   'nationality': 'Germany',
#   'height': '192 cm',
#   'weight': '85 kg',
#   'photo': 'https://media.api-sports.io/football/coachs/40.png',
#   'team': {'id': 49,
#    'name': 'Chelsea',
#    'logo': 'https://media.api-sports.io/football/teams/49.png'},
#   'career': [{'team': {'id': 49,
#      'name': 'Chelsea',
#      'logo': 'https://media.api-sports.io/football/teams/49.png'},
#     'start': '2021-01-01',
#     'end': None},
#    {'team': {'id': 85,
#      'name': 'PSG',
#      'logo': 'https://media.api-sports.io/football/teams/85.png'},
#     'start': '2018-07-01',
#     'end': '2020-12-01'},
#    {'team': {'id': 165,
#      'name': 'Borussia Dortmund',
#      'logo': 'https://media.api-sports.io/football/teams/165.png'},
#     'start': '2015-07-01',
#     'end': '2017-05-01'},
#    {'team': {'id': None, 'name': 'Mainz', 'logo': None},
#     'start': '2009-08-01',
#     'end': '2014-05-01'}]}]

# %%
aa['response'][0]['name']
# Out:
# 'E. ten Hag'

# %%
import requests

url = "https://football-betting-odds1.p.rapidapi.com/provider1/live/upcoming"

headers = {
	"X-RapidAPI-Key": "b7cf950dddmsh7909c2d31444039p1a7716jsnaed17a1b9be9",
	"X-RapidAPI-Host": "football-betting-odds1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
print(type(response.json()))
print(response.json())
al = response.json()
# Out:
# {"1411138803131123":{"mid":"1411138803131123","home":"Beitar Jerusalem FC","away":"Bnei Sakhnin FC","country_leagues":"Israel - Premier League","leagues":"Premier League","country":"Israel","score":"0-0","home_score":0,"away_score":0,"periodID":"","periodTXT":"","periodTime":1668447664,"startTime":1668449700,"lastUpdateTime":1668447545,"minutes":0,"status":"1","importancy":6,"odds":{"home":"2.40","draw":"3.10","away":"2.60","1st-1":"3.10","1st-0":"2.00","1st-2":"3.25","2nd-1":"2.75","2nd-0":"2.37","2nd-2":"2.90","both-team-score-yes":"1.75","both-team-score-no":"1.83","1st-both-team-score-yes":"4.28","1st-both-team-score-no":"1.17","double-chance-1-0":"1.43","double-chance-0-2":"1.49","double-chance-1-2":"1.32","draw-refund-1":"1.78","draw-refund-2":"1.90","total-goal-0":"7.43","total-goal-1":"3.90","total-goal-2":"3.15","total-goal-3":"3.60","total-goal-4":"5.18","total-goal-5":"9.00","away-total-goal-0":"2.70","away-total-goal-1":"2.25","away-total-goal-2":"3.51","away-total-goal-3+":"5.40","home-total-goal-0":"2.88","home-total-goal-1":"2.30","home-total-goal-2":"3.38","home-total-goal-3+":"4.95","1st-total-goal-0":"2.34","1st-total-goal-1":"2.25","1st-total-goal-2":"3.69","1st-total-goal-3+":"6.98","total-goal-0-1":"2.79","total-goal-2-3":"1.80","total-goal-4+":"2.97","total-goal-0-2":"1.75","total-goal-3-4":"2.30","total-goal-5+":"5.85","total-goal-0-3":"1.28","total-goal-4-5":"3.60","total-goal-6+":"11.70","next-goal-1-1":"1.88","next-goal-1-0":"7.84","next-goal-1-2":"1.95","1-hcap-1-+1":"1.43","1-hcap-0-+1":"3.90","1-hcap-2--1":"4.95","1-hcap-1--1":"4.50","1-hcap-0--1":"3.69","1-hcap-2-+1":"1.49","over-2-5":"1.95","under-2-5":"1.75","over-1-5":"1.32","under-1-5":"3.10","over-3-5":"3.30","under-3-5":"1.28","over-0-5":"1.06","under-0-5":"8.25","over-4-5":"6.50","under-4-5":"1.10","over-5-5":"13.00","under-5-5":"1.03","away-over-1-5":"2.55","away-under-1-5":"1.46","away-over-0-5":"1.33","away-under-0-5":"3.00","away-over-2-5":"6.00","away-under-2-5":"1.11","away-under-3-5":"1.02","home-over-1-5":"2.40","home-under-1-5":"1.49","home-over-0-5":"1.31","home-under-0-5":"3.20","home-over-2-5":"5.50","home-under-2-5":"1.12","home-over-3-5":"14.00","home-under-3-5":"1.02","1st-over-1-5":"2.90","1st-under-1-5":"1.36","1st-over-0-5":"1.42","1st-under-0-5":"2.60","1st-over-2-5":"7.75","1st-under-2-5":"1.07","1st-under-3-5":"1.00","away-1st-over-0-5":"2.20","away-1st-under-0-5":"1.60","away-1st-over-1-5":"7.50","away-1st-under-1-5":"1.07","home-1st-over-0-5":"2.10","home-1st-under-0-5":"1.63","home-1st-over-1-5":"7.00","home-1st-under-1-5":"1.08","2nd-over-1-5":"2.10","2nd-under-1-5":"1.63","2nd-over-0-5":"1.25","2nd-under-0-5":"3.60","2nd-over-2-5":"4.50","2nd-under-2-5":"1.17","1-hcap-1--2":"10.35","1-hcap-0--2":"6.53","1-hcap-2-+2":"1.15"}},"1411145117138820":{"mid":"1411145117138820","home":"Chelmsford City","away":"Barnet","country_leagues":"England - FA Cup","leagues":"FA Cup","country":"England","score":"0-0","home_score":0,"away_score":0,"periodID":"","periodTXT":"","periodTime":1668447664,"startTime":1668454200,"lastUpdateTime":1668447545,"minutes":0,"status":"1","importancy":21,"odds":{"home":"2.60","draw":"3.40","away":"2.35","1st-1":"3.10","1st-0":"2.15","1st-2":"2.90","2nd-1":"2.85","2nd-0":"2.55","2nd-2":"2.65","both-team-score-yes":"1.58","both-team-score-no":"2.09","1st-both-team-score-yes":"3.61","1st-both-team-score-no":"1.23","double-chance-1-0":"1.53","double-chance-0-2":"1.44","double-chance-1-2":"1.28","draw-refund-1":"1.93","draw-refund-2":"1.75","total-goal-0":"9.90","total-goal-1":"4.73","total-goal-2":"3.38","total-goal-3":"3.51","total-goal-4":"4.50","total-goal-5":"7.20","total-goal-6":"12.15","away-total-goal-0":"3.38","away-total-goal-1":"2.39","away-total-goal-2":"3.15","away-total-goal-3+":"3.96","home-total-goal-0":"3.15","home-total-goal-1":"2.34","home-total-goal-2":"3.24","home-total-goal-3+":"4.32","1st-total-goal-0":"2.70","1st-total-goal-1":"2.30","1st-total-goal-2":"3.33","1st-total-goal-3+":"5 ...
# <class 'dict'>
# {'1411138803131123': {'mid': '1411138803131123', 'home': 'Beitar Jerusalem FC', 'away': 'Bnei Sakhnin FC', 'country_leagues': 'Israel - Premier League', 'leagues': 'Premier League', 'country': 'Israel', 'score': '0-0', 'home_score': 0, 'away_score': 0, 'periodID': '', 'periodTXT': '', 'periodTime': 1668447664, 'startTime': 1668449700, 'lastUpdateTime': 1668447545, 'minutes': 0, 'status': '1', 'importancy': 6, 'odds': {'home': '2.40', 'draw': '3.10', 'away': '2.60', '1st-1': '3.10', '1st-0': '2.00', '1st-2': '3.25', '2nd-1': '2.75', '2nd-0': '2.37', '2nd-2': '2.90', 'both-team-score-yes': '1.75', 'both-team-score-no': '1.83', '1st-both-team-score-yes': '4.28', '1st-both-team-score-no': '1.17', 'double-chance-1-0': '1.43', 'double-chance-0-2': '1.49', 'double-chance-1-2': '1.32', 'draw-refund-1': '1.78', 'draw-refund-2': '1.90', 'total-goal-0': '7.43', 'total-goal-1': '3.90', 'total-goal-2': '3.15', 'total-goal-3': '3.60', 'total-goal-4': '5.18', 'total-goal-5': '9.00', 'away-total-goal-0': '2.70', 'away-total-goal-1': '2.25', 'away-total-goal-2': '3.51', 'away-total-goal-3+': '5.40', 'home-total-goal-0': '2.88', 'home-total-goal-1': '2.30', 'home-total-goal-2': '3.38', 'home-total-goal-3+': '4.95', '1st-total-goal-0': '2.34', '1st-total-goal-1': '2.25', '1st-total-goal-2': '3.69', '1st-total-goal-3+': '6.98', 'total-goal-0-1': '2.79', 'total-goal-2-3': '1.80', 'total-goal-4+': '2.97', 'total-goal-0-2': '1.75', 'total-goal-3-4': '2.30', 'total-goal-5+': '5.85', 'total-goal-0-3': '1.28', 'total-goal-4-5': '3.60', 'total-goal-6+': '11.70', 'next-goal-1-1': '1.88', 'next-goal-1-0': '7.84', 'next-goal-1-2': '1.95', '1-hcap-1-+1': '1.43', '1-hcap-0-+1': '3.90', '1-hcap-2--1': '4.95', '1-hcap-1--1': '4.50', '1-hcap-0--1': '3.69', '1-hcap-2-+1': '1.49', 'over-2-5': '1.95', 'under-2-5': '1.75', 'over-1-5': '1.32', 'under-1-5': '3.10', 'over-3-5': '3.30', 'under-3-5': '1.28', 'over-0-5': '1.06', 'under-0-5': '8.25', 'over-4-5': '6.50', 'under-4-5': '1.10', 'over-5-5': '13.00', 'under-5-5': '1.03', 'away-over-1-5': '2.55', 'away-under-1-5': '1.46', 'away-over-0-5': '1.33', 'away-under-0-5': '3.00', 'away-over-2-5': '6.00', 'away-under-2-5': '1.11', 'away-under-3-5': '1.02', 'home-over-1-5': '2.40', 'home-under-1-5': '1.49', 'home-over-0-5': '1.31', 'home-under-0-5': '3.20', 'home-over-2-5': '5.50', 'home-under-2-5': '1.12', 'home-over-3-5': '14.00', 'home-under-3-5': '1.02', '1st-over-1-5': '2.90', '1st-under-1-5': '1.36', '1st-over-0-5': '1.42', '1st-under-0-5': '2.60', '1st-over-2-5': '7.75', '1st-under-2-5': '1.07', '1st-under-3-5': '1.00', 'away-1st-over-0-5': '2.20', 'away-1st-under-0-5': '1.60', 'away-1st-over-1-5': '7.50', 'away-1st-under-1-5': '1.07', 'home-1st-over-0-5': '2.10', 'home-1st-under-0-5': '1.63', 'home-1st-over-1-5': '7.00', 'home-1st-under-1-5': '1.08', '2nd-over-1-5': '2.10', '2nd-under-1-5': '1.63', '2nd-over-0-5': '1.25', '2nd-under-0-5': '3.60', '2nd-over-2-5': '4.50', '2nd-under-2-5': '1.17', '1-hcap-1--2': '10.35', '1-hcap-0--2': '6.53', '1-hcap-2-+2': '1.15'}}, '1411145117138820': {'mid': '1411145117138820', 'home': 'Chelmsford City', 'away': 'Barnet', 'country_leagues': 'England - FA Cup', 'leagues': 'FA Cup', 'country': 'England', 'score': '0-0', 'home_score': 0, 'away_score': 0, 'periodID': '', 'periodTXT': '', 'periodTime': 1668447664, 'startTime': 1668454200, 'lastUpdateTime': 1668447545, 'minutes': 0, 'status': '1', 'importancy': 21, 'odds': {'home': '2.60', 'draw': '3.40', 'away': '2.35', '1st-1': '3.10', '1st-0': '2.15', '1st-2': '2.90', '2nd-1': '2.85', '2nd-0': '2.55', '2nd-2': '2.65', 'both-team-score-yes': '1.58', 'both-team-score-no': '2.09', '1st-both-team-score-yes': '3.61', '1st-both-team-score-no': '1.23', 'double-chance-1-0': '1.53', 'double-chance-0-2': '1.44', 'double-chance-1-2': '1.28', 'draw-refund-1': '1.93', 'draw-refund-2': '1.75', 'total-goal-0': '9.90', 'total-goal-1': '4.73', 'total-goal-2': '3.38', 'total-goal-3': '3.51', 'total-goal-4': '4.50', 'total-goal-5': '7.20', 'total-goal ...

# %%
al.keys()
# Out:
# dict_keys(['1411138803131123', '1411145117138820', '1411149080149234', '1411151214151392', '1411182912183224', '1411195495195542', '1411195747195745', '1411195750195746', '1411196255196256', '1411197297197275', '1411197302197303', '1411198662205687', '1411199174256956', '1411199198199231', '1411199210199204', '1411199234199217', '1411204887196012', '1411233478318724', '1411234101234110', '1411234120196231', '1411234241234233', '1411245508298369', '1411246530251353', '1411246535246529', '1411246537251346', '1411246552251468', '1411246566246572', '1411246573246534', '1411251043196129', '1411251350246531', '1411251351246527', '1411262477262726', '1411303933233494', '1411304146233467', '1411305072256176', '1511148506148612', '1511166533144445', '1511168213199707', '1511169042144043', '1511169445138832', '1511192845192839', '1511196516196499', '1511196518196493', '1511199438262725', '1511209405209395', '1511211338199449', '1511233506138824', '1511255501260834', '1511260656315356', '1511262578212630', '1511263048199440', '1611138827172230', '1611166816171123', '1611232529202314', '1611253271197295'])
