# %%
import pandas as pd
from PIL import Image
import requests
from IPython.display import Image

# %%
df = pd.read_csv("fifa23.csv")
df.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  LM Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# ...

# %%
df['Image Link'][0]
# Out:
# 'https://cdn.sofifa.net/players/158/023/23_60.png'

# %%
window = Tk()
window.title("Add Image")
window = Canvas(window, width = 450, height = 450)
window.pack()
image PhotoImage(file = get_url)

# %%
im = Image.open(requests.get('https://cdn.sofifa.net/players/158/023/23_60.png'
, stream=True).raw)

# %%
im = im.resize((300, 300))

# %%
im
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x283D42ACA30>

# %%
im.resize(im.size)
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x283D42ACBB0>

# %%
#goldcard = Image(filename = "gold1.png", width = 500)
#goldcard

# %%
import cv2 as cv2

# %%
gc = goldcard.resize(goldcard.size)
gc
# Out:
# <PIL.Image.Image image mode=RGBA size=644x900 at 0x283D2CADDF0>

# %%
goldcard = Image.open("gold1.png")

# %%
print(f"Original size : {im.size}")
# Out:
# Original size : (60, 60)

# %%
from PIL import Image, ImageDraw, ImageFont

# %%
width, height = im.size # 400x266

# %%
draw = ImageDraw.Draw(im)
text = "Sunset"

# %%
from PIL import Image

# Open overlay image
img = im
img_w, img_h = img.size

img.putalpha(0)

background = goldcard
bg_w, bg_h = background.size
offset = ((bg_w - img_w) // 2, (bg_h - img_h) // 2)
background.paste(img, offset,)
background.save('result.png')

# %%
background
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=644x900 at 0x283D3574D00>

# %%
from PIL import Image
img = im#Image.open('gold1.png')
img_w, img_h = img.size
background = Image.new('RGBA', (1440, 900), (255, 255, 255, 255))
bg_w, bg_h = background.size
offset = ((bg_w - img_w) // 2, (bg_h - img_h) // 2)
background.paste(img, offset)
background.save('out.png')

# %%
background
# Out:
# <PIL.Image.Image image mode=RGBA size=1440x900 at 0x283D3100640>

# %%
im
goldcard
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=644x900 at 0x283D3574D00>

# %%
im
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x283D42AC8B0>
