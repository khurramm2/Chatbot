# %%
import pandas as pd
from PIL import Image
import requests
from IPython.display import Image
from PIL import Image, ImageDraw, ImageFont
import cv2 as cv2

# %%
stats = pd.read_csv("fifa23.csv")

# %%
stats.head()
# Out:
#          Known As           Full Name  Overall  Potential  Value(in Euro)  \
# 0        L. Messi        Lionel Messi       91         91        54000000
# 1      K. Benzema       Karim Benzema       91         91        64000000
# 2  R. Lewandowski  Robert Lewandowski       91         91        84000000
# 3    K. De Bruyne     Kevin De Bruyne       91         91       107500000
# 4       K. Mbappé       Kylian Mbappé       91         95       190500000
#
#   Positions Played Best Position Nationality  \
# 0               RW           CAM   Argentina
# 1            CF,ST            CF      France
# 2               ST            ST      Poland
# 3           CM,CAM            CM     Belgium
# 4            ST,LW            ST      France
#
#                                          Image Link  Age  ...  LM Rating  \
# 0  https://cdn.sofifa.net/players/158/023/23_60.png   35  ...         91
# 1  https://cdn.sofifa.net/players/165/153/23_60.png   34  ...         89
# ...

# %%
#playerpic = Image.open(requests.get('https://cdn.sofifa.net/players/158/023/23_60.png'
#, stream=True).raw)

# %%
playerpic = Image.open(requests.get(stats['Image Link'][cavalue]
, stream=True).raw)

# %%
playerpic = playerpic.resize((300, 300))
goldcard1 = goldcard.resize((650, 900))

# %%
#print(f"Original size : {playerpic.size}")
#print(f"Original size : {goldcard.size}")
# Out:
# Original size : (300, 300)
# Original size : (644, 900)

# %%
goldcard = Image.open("gold1.png")

area = (165,170,465,470)

jj = goldcard.paste(playerpic, area)

goldcard
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=644x900 at 0x1F18E286A00>

# %%
def playericon(cavalue):
    playerpic = Image.open(requests.get(stats['Image Link'][cavalue], stream=True).raw)
    playerpic = playerpic.resize((300, 300))
    goldcard1 = goldcard.resize((650, 900))
    
    goldcard = Image.open("gold1.png")

    area = (165,170,465,470)

    jj = goldcard.paste(playerpic, area)

    goldcard
    
    
    
    
    
playericon(0)
