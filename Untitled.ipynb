# %%
import requests

url = "https://api-football-beta.p.rapidapi.com/odds/bets"

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "api-football-beta.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print (type(response.json()))
print(response.json())
df = response.json()
# Out:
# <class 'dict'>
# {'get': 'odds/bets', 'parameters': [], 'errors': [], 'results': 91, 'paging': {'current': 1, 'total': 1}, 'response': [{'id': 1, 'name': 'Match Winner'}, {'id': 2, 'name': 'Home/Away'}, {'id': 3, 'name': 'Second Half Winner'}, {'id': 4, 'name': 'Asian Handicap'}, {'id': 5, 'name': 'Goals Over/Under'}, {'id': 6, 'name': 'Goals Over/Under First Half'}, {'id': 7, 'name': 'HT/FT Double'}, {'id': 8, 'name': 'Both Teams Score'}, {'id': 9, 'name': 'Handicap Result'}, {'id': 10, 'name': 'Exact Score'}, {'id': 11, 'name': 'Highest Scoring Half'}, {'id': 12, 'name': 'Double Chance'}, {'id': 13, 'name': 'First Half Winner'}, {'id': 14, 'name': 'Team To Score First'}, {'id': 15, 'name': 'Team To Score Last'}, {'id': 16, 'name': 'Total - Home'}, {'id': 17, 'name': 'Total - Away'}, {'id': 18, 'name': 'Handicap Result - First Half'}, {'id': 19, 'name': 'Asian Handicap First Half'}, {'id': 20, 'name': 'Double Chance - First Half'}, {'id': 21, 'name': 'Odd/Even'}, {'id': 22, 'name': 'Odd/Even - First Half'}, {'id': 23, 'name': 'Home Odd/Even'}, {'id': 24, 'name': 'Results/Both Teams Score'}, {'id': 25, 'name': 'Result/Total Goals'}, {'id': 26, 'name': 'Goals Over/Under - Second Half'}, {'id': 27, 'name': 'Clean Sheet - Home'}, {'id': 28, 'name': 'Clean Sheet - Away'}, {'id': 29, 'name': 'Win to Nil - Home'}, {'id': 30, 'name': 'Win to Nil - Away'}, {'id': 31, 'name': 'Correct Score - First Half'}, {'id': 32, 'name': 'Win Both Halves'}, {'id': 33, 'name': 'Double Chance - Second Half'}, {'id': 34, 'name': 'Both Teams Score - First Half'}, {'id': 35, 'name': 'Both Teams To Score - Second Half'}, {'id': 36, 'name': 'Win To Nil'}, {'id': 37, 'name': 'Home win both halves'}, {'id': 38, 'name': 'Exact Goals Number'}, {'id': 39, 'name': 'To Win Either Half'}, {'id': 40, 'name': 'Home Team Exact Goals Number'}, {'id': 41, 'name': 'Away Team Exact Goals Number'}, {'id': 42, 'name': 'Second Half Exact Goals Number'}, {'id': 43, 'name': 'Home Team Score a Goal'}, {'id': 44, 'name': 'Away Team Score a Goal'}, {'id': 45, 'name': 'Corners Over Under'}, {'id': 46, 'name': 'Exact Goals Number - First Half'}, {'id': 47, 'name': 'Winning Margin'}, {'id': 48, 'name': 'To Score In Both Halves By Teams'}, {'id': 49, 'name': 'Total Goals/Both Teams To Score'}, {'id': 50, 'name': 'Goal Line'}, {'id': 51, 'name': 'Halftime Result/Total Goals'}, {'id': 52, 'name': 'Halftime Result/Both Teams Score'}, {'id': 53, 'name': 'Away win both halves'}, {'id': 54, 'name': 'First 10 min Winner'}, {'id': 55, 'name': 'Corners 1x2'}, {'id': 56, 'name': 'Corners Asian Handicap'}, {'id': 57, 'name': 'Home Corners Over/Under'}, {'id': 58, 'name': 'Away Corners Over/Under'}, {'id': 59, 'name': 'Own Goal'}, {'id': 60, 'name': 'Away Odd/Even'}, {'id': 61, 'name': 'To Qualify'}, {'id': 62, 'name': 'Correct Score - Second Half'}, {'id': 63, 'name': 'Odd/Even - Second Half'}, {'id': 72, 'name': 'Goal Line (1st Half)'}, {'id': 73, 'name': 'Both Teams to Score 1st Half - 2nd Half'}, {'id': 74, 'name': '10 Over/Under'}, {'id': 75, 'name': 'Last Corner'}, {'id': 76, 'name': 'First Corner'}, {'id': 77, 'name': 'Total Corners (1st Half)'}, {'id': 78, 'name': 'RTG_H1'}, {'id': 79, 'name': 'Cards European Handicap'}, {'id': 80, 'name': 'Cards Over/Under'}, {'id': 81, 'name': 'Cards Asian Handicap'}, {'id': 82, 'name': 'Home Team Total Cards'}, {'id': 83, 'name': 'Away Team Total Cards'}, {'id': 84, 'name': 'Total Corners (3 way) (1st Half)'}, {'id': 85, 'name': 'Total Corners (3 way)'}, {'id': 86, 'name': 'RCARD'}, {'id': 87, 'name': 'Total ShotOnGoal'}, {'id': 88, 'name': 'Home Total ShotOnGoal'}, {'id': 89, 'name': 'Away Total ShotOnGoal'}, {'id': 91, 'name': 'Total Goals (3 way)'}, {'id': 92, 'name': 'Anytime Goal Scorer'}, {'id': 93, 'name': 'First Goal Scorer'}, {'id': 94, 'name': 'Last Goal Scorer'}, {'id': 95, 'name': 'To Score Two or More Goals'}, {'id': 96, 'name': 'Last Goal Scorer'}, {'id': 97, 'name': 'First Goal Method'}, {'id': 99, 'name': 'To Score A Penalty'}, {'id': 100, 'name': 'T ...

# %%
import requests

url = "https://api-football-beta.p.rapidapi.com/teams/statistics"

querystring = {"team":"33","season":"2019","league":"39"}

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "api-football-beta.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print (type(response.json()))
print(response.json())
df = response.json()
# Out:
# <class 'dict'>
# {'get': 'teams/statistics', 'parameters': {'league': '39', 'team': '33', 'season': '2019'}, 'errors': [], 'results': 11, 'paging': {'current': 1, 'total': 1}, 'response': {'league': {'id': 39, 'name': 'Premier League', 'country': 'England', 'logo': 'https://media.api-sports.io/football/leagues/39.png', 'flag': 'https://media.api-sports.io/flags/gb.svg', 'season': 2019}, 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media.api-sports.io/football/teams/33.png'}, 'form': 'WDLDWLDLDWLWDDWWDLWWLWLLDWWDWDWWWWDWDW', 'fixtures': {'played': {'home': 19, 'away': 19, 'total': 38}, 'wins': {'home': 10, 'away': 8, 'total': 18}, 'draws': {'home': 7, 'away': 5, 'total': 12}, 'loses': {'home': 2, 'away': 6, 'total': 8}}, 'goals': {'for': {'total': {'home': 40, 'away': 26, 'total': 66}, 'average': {'home': '2.1', 'away': '1.4', 'total': '1.7'}, 'minute': {'0-15': {'total': 4, 'percentage': '6.06%'}, '16-30': {'total': 17, 'percentage': '25.76%'}, '31-45': {'total': 11, 'percentage': '16.67%'}, '46-60': {'total': 13, 'percentage': '19.70%'}, '61-75': {'total': 10, 'percentage': '15.15%'}, '76-90': {'total': 8, 'percentage': '12.12%'}, '91-105': {'total': 3, 'percentage': '4.55%'}, '106-120': {'total': None, 'percentage': None}}}, 'against': {'total': {'home': 17, 'away': 19, 'total': 36}, 'average': {'home': '0.9', 'away': '1.0', 'total': '0.9'}, 'minute': {'0-15': {'total': 6, 'percentage': '16.67%'}, '16-30': {'total': 3, 'percentage': '8.33%'}, '31-45': {'total': 7, 'percentage': '19.44%'}, '46-60': {'total': 9, 'percentage': '25.00%'}, '61-75': {'total': 3, 'percentage': '8.33%'}, '76-90': {'total': 5, 'percentage': '13.89%'}, '91-105': {'total': 3, 'percentage': '8.33%'}, '106-120': {'total': None, 'percentage': None}}}}, 'biggest': {'streak': {'wins': 4, 'draws': 2, 'loses': 2}, 'wins': {'home': '4-0', 'away': '0-3'}, 'loses': {'home': '0-2', 'away': '2-0'}, 'goals': {'for': {'home': 5, 'away': 3}, 'against': {'home': 2, 'away': 3}}}, 'clean_sheet': {'home': 7, 'away': 6, 'total': 13}, 'failed_to_score': {'home': 2, 'away': 6, 'total': 8}, 'penalty': {'scored': {'total': 10, 'percentage': '100.00%'}, 'missed': {'total': 0, 'percentage': '0%'}, 'total': 10}, 'lineups': [{'formation': '4-2-3-1', 'played': 32}, {'formation': '3-4-1-2', 'played': 4}, {'formation': '3-4-2-1', 'played': 1}, {'formation': '4-3-1-2', 'played': 1}], 'cards': {'yellow': {'0-15': {'total': 5, 'percentage': '6.85%'}, '16-30': {'total': 5, 'percentage': '6.85%'}, '31-45': {'total': 16, 'percentage': '21.92%'}, '46-60': {'total': 12, 'percentage': '16.44%'}, '61-75': {'total': 14, 'percentage': '19.18%'}, '76-90': {'total': 21, 'percentage': '28.77%'}, '91-105': {'total': None, 'percentage': None}, '106-120': {'total': None, 'percentage': None}}, 'red': {'0-15': {'total': None, 'percentage': None}, '16-30': {'total': None, 'percentage': None}, '31-45': {'total': None, 'percentage': None}, '46-60': {'total': None, 'percentage': None}, '61-75': {'total': None, 'percentage': None}, '76-90': {'total': None, 'percentage': None}, '91-105': {'total': None, 'percentage': None}, '106-120': {'total': None, 'percentage': None}}}}}

# %%
df['response']['team']['name']
# Out:
# 'Manchester United'

# %%
import requests

url = "https://api-football-beta.p.rapidapi.com/standings"

querystring = {"season":"2019","league":"39"}

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "api-football-beta.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print (type(response.json()))
print(response.json())
df = response.json()
# Out:
# <class 'dict'>
# {'get': 'standings', 'parameters': {'league': '39', 'season': '2019'}, 'errors': [], 'results': 1, 'paging': {'current': 1, 'total': 1}, 'response': [{'league': {'id': 39, 'name': 'Premier League', 'country': 'England', 'logo': 'https://media.api-sports.io/football/leagues/39.png', 'flag': 'https://media.api-sports.io/flags/gb.svg', 'season': 2019, 'standings': [[{'rank': 1, 'team': {'id': 40, 'name': 'Liverpool', 'logo': 'https://media.api-sports.io/football/teams/40.png'}, 'points': 99, 'goalsDiff': 52, 'group': 'Premier League', 'form': 'WWLDW', 'status': 'same', 'description': 'Promotion - Champions League (Group Stage)', 'all': {'played': 38, 'win': 32, 'draw': 3, 'lose': 3, 'goals': {'for': 85, 'against': 33}}, 'home': {'played': 19, 'win': 18, 'draw': 1, 'lose': 0, 'goals': {'for': 52, 'against': 16}}, 'away': {'played': 19, 'win': 14, 'draw': 2, 'lose': 3, 'goals': {'for': 33, 'against': 17}}, 'update': '2020-07-26T00:00:00+00:00'}, {'rank': 2, 'team': {'id': 50, 'name': 'Manchester City', 'logo': 'https://media.api-sports.io/football/teams/50.png'}, 'points': 81, 'goalsDiff': 67, 'group': 'Premier League', 'form': 'WWWWW', 'status': 'same', 'description': 'Promotion - Champions League (Group Stage)', 'all': {'played': 38, 'win': 26, 'draw': 3, 'lose': 9, 'goals': {'for': 102, 'against': 35}}, 'home': {'played': 19, 'win': 15, 'draw': 2, 'lose': 2, 'goals': {'for': 57, 'against': 13}}, 'away': {'played': 19, 'win': 11, 'draw': 1, 'lose': 7, 'goals': {'for': 45, 'against': 22}}, 'update': '2020-07-26T00:00:00+00:00'}, {'rank': 3, 'team': {'id': 33, 'name': 'Manchester United', 'logo': 'https://media.api-sports.io/football/teams/33.png'}, 'points': 66, 'goalsDiff': 30, 'group': 'Premier League', 'form': 'WDWDW', 'status': 'same', 'description': 'Promotion - Champions League (Group Stage)', 'all': {'played': 38, 'win': 18, 'draw': 12, 'lose': 8, 'goals': {'for': 66, 'against': 36}}, 'home': {'played': 19, 'win': 10, 'draw': 7, 'lose': 2, 'goals': {'for': 40, 'against': 17}}, 'away': {'played': 19, 'win': 8, 'draw': 5, 'lose': 6, 'goals': {'for': 26, 'against': 19}}, 'update': '2020-07-26T00:00:00+00:00'}, {'rank': 4, 'team': {'id': 49, 'name': 'Chelsea', 'logo': 'https://media.api-sports.io/football/teams/49.png'}, 'points': 66, 'goalsDiff': 15, 'group': 'Premier League', 'form': 'WLWLW', 'status': 'same', 'description': 'Promotion - Champions League (Group Stage)', 'all': {'played': 38, 'win': 20, 'draw': 6, 'lose': 12, 'goals': {'for': 69, 'against': 54}}, 'home': {'played': 19, 'win': 11, 'draw': 3, 'lose': 5, 'goals': {'for': 30, 'against': 16}}, 'away': {'played': 19, 'win': 9, 'draw': 3, 'lose': 7, 'goals': {'for': 39, 'against': 38}}, 'update': '2020-07-26T00:00:00+00:00'}, {'rank': 5, 'team': {'id': 46, 'name': 'Leicester', 'logo': 'https://media.api-sports.io/football/teams/46.png'}, 'points': 62, 'goalsDiff': 26, 'group': 'Premier League', 'form': 'LLWLD', 'status': 'same', 'description': 'Promotion - Europa League (Group Stage)', 'all': {'played': 38, 'win': 18, 'draw': 8, 'lose': 12, 'goals': {'for': 67, 'against': 41}}, 'home': {'played': 19, 'win': 11, 'draw': 4, 'lose': 4, 'goals': {'for': 35, 'against': 17}}, 'away': {'played': 19, 'win': 7, 'draw': 4, 'lose': 8, 'goals': {'for': 32, 'against': 24}}, 'update': '2020-07-26T00:00:00+00:00'}, {'rank': 6, 'team': {'id': 47, 'name': 'Tottenham', 'logo': 'https://media.api-sports.io/football/teams/47.png'}, 'points': 59, 'goalsDiff': 14, 'group': 'Premier League', 'form': 'DWWWD', 'status': 'same', 'description': 'Promotion - Europa League (Qualification)', 'all': {'played': 38, 'win': 16, 'draw': 11, 'lose': 11, 'goals': {'for': 61, 'against': 47}}, 'home': {'played': 19, 'win': 12, 'draw': 3, 'lose': 4, 'goals': {'for': 36, 'against': 17}}, 'away': {'played': 19, 'win': 4, 'draw': 8, 'lose': 7, 'goals': {'for': 25, 'against': 30}}, 'update': '2020-07-26T00:00:00+00:00'}, {'rank': 7, 'team': {'id': 39, 'name': 'Wolves', 'logo': 'https://media.api-sports.io/foot ...

# %%
df['response'][0]['league'].keys()
# Out:
# dict_keys(['id', 'name', 'country', 'logo', 'flag', 'season', 'standings'])

# %%
df['response'][0]['league']
# Out:
# {'id': 39,
#  'name': 'Premier League',
#  'country': 'England',
#  'logo': 'https://media.api-sports.io/football/leagues/39.png',
#  'flag': 'https://media.api-sports.io/flags/gb.svg',
#  'season': 2019,
#  'standings': [[{'rank': 1,
#     'team': {'id': 40,
#      'name': 'Liverpool',
#      'logo': 'https://media.api-sports.io/football/teams/40.png'},
#     'points': 99,
#     'goalsDiff': 52,
#     'group': 'Premier League',
#     'form': 'WWLDW',
#     'status': 'same',
#     'description': 'Promotion - Champions League (Group Stage)',
#     'all': {'played': 38,
#      'win': 32,
#      'draw': 3,
#      'lose': 3,
#      'goals': {'for': 85, 'against': 33}},
#     'home': {'played': 19,
#      'win': 18,
#      'draw': 1,
#      'lose': 0,
#      'goals': {'for': 52, 'against': 16}},
#     'away': {'played': 19,
#      'win': 14,
#      'draw': 2,
#      'lose': 3,
#      'goals': {'for': 33, 'against': 17}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 2,
#     'team': {'id': 50,
#      'name': 'Manchester City',
#      'logo': 'https://media.api-sports.io/football/teams/50.png'},
#     'points': 81,
#     'goalsDiff': 67,
#     'group': 'Premier League',
#     'form': 'WWWWW',
#     'status': 'same',
#     'description': 'Promotion - Champions League (Group Stage)',
#     'all': {'played': 38,
#      'win': 26,
#      'draw': 3,
#      'lose': 9,
#      'goals': {'for': 102, 'against': 35}},
#     'home': {'played': 19,
#      'win': 15,
#      'draw': 2,
#      'lose': 2,
#      'goals': {'for': 57, 'against': 13}},
#     'away': {'played': 19,
#      'win': 11,
#      'draw': 1,
#      'lose': 7,
#      'goals': {'for': 45, 'against': 22}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 3,
#     'team': {'id': 33,
#      'name': 'Manchester United',
#      'logo': 'https://media.api-sports.io/football/teams/33.png'},
#     'points': 66,
#     'goalsDiff': 30,
#     'group': 'Premier League',
#     'form': 'WDWDW',
#     'status': 'same',
#     'description': 'Promotion - Champions League (Group Stage)',
#     'all': {'played': 38,
#      'win': 18,
#      'draw': 12,
#      'lose': 8,
#      'goals': {'for': 66, 'against': 36}},
#     'home': {'played': 19,
#      'win': 10,
#      'draw': 7,
#      'lose': 2,
#      'goals': {'for': 40, 'against': 17}},
#     'away': {'played': 19,
#      'win': 8,
#      'draw': 5,
#      'lose': 6,
#      'goals': {'for': 26, 'against': 19}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 4,
#     'team': {'id': 49,
#      'name': 'Chelsea',
#      'logo': 'https://media.api-sports.io/football/teams/49.png'},
#     'points': 66,
#     'goalsDiff': 15,
#     'group': 'Premier League',
#     'form': 'WLWLW',
#     'status': 'same',
#     'description': 'Promotion - Champions League (Group Stage)',
#     'all': {'played': 38,
#      'win': 20,
#      'draw': 6,
#      'lose': 12,
#      'goals': {'for': 69, 'against': 54}},
#     'home': {'played': 19,
#      'win': 11,
#      'draw': 3,
#      'lose': 5,
#      'goals': {'for': 30, 'against': 16}},
#     'away': {'played': 19,
#      'win': 9,
#      'draw': 3,
#      'lose': 7,
#      'goals': {'for': 39, 'against': 38}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 5,
#     'team': {'id': 46,
#      'name': 'Leicester',
#      'logo': 'https://media.api-sports.io/football/teams/46.png'},
#     'points': 62,
#     'goalsDiff': 26,
#     'group': 'Premier League',
#     'form': 'LLWLD',
#     'status': 'same',
#     'description': 'Promotion - Europa League (Group Stage)',
#     'all': {'played': 38,
#      'win': 18,
#      'draw': 8,
#      'lose': 12,
#      'goals': {'for': 67, 'against': 41}},
#     'home': {'played': 19,
#      'win': 11,
#      'draw': 4,
#      'lose': 4,
#      'goals': {'for': 35, 'against': 17}},
#     'away': {'played': 19,
#      'win': 7,
#      'draw': 4,
#      'lose': 8,
#      'goals': {'for': 32, 'against': 24}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 6,
#     'team': {'id': 47,
#      'name': 'Tottenham',
#      'logo': 'https://media.api-sports.io/football/teams/47.png'},
#     'points': 59,
#     'goalsDiff': 14,
#     'group': 'Premier League',
#     'form': 'DWWWD',
#     'status': 'same',
#     'description': 'Promotion - Europa League (Qualification)',
#     'all': {'played': 38,
#      'win': 16,
#      'draw': 11,
#      'lose': 11,
#      'goals': {'for': 61, 'against': 47}},
#     'home': {'played': 19,
#      'win': 12,
#      'draw': 3,
#      'lose': 4,
#      'goals': {'for': 36, 'against': 17}},
#     'away': {'played': 19,
#      'win': 4,
#      'draw': 8,
#      'lose': 7,
#      'goals': {'for': 25, 'against': 30}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 7,
#     'team': {'id': 39,
#      'name': 'Wolves',
#      'logo': 'https://media.api-sports.io/football/teams/39.png'},
#     'points': 59,
#     'goalsDiff': 11,
#     'group': 'Premier League',
#     'form': 'LWDWL',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 15,
#      'draw': 14,
#      'lose': 9,
#      'goals': {'for': 51, 'against': 40}},
#     'home': {'played': 19,
#      'win': 8,
#      'draw': 7,
#      'lose': 4,
#      'goals': {'for': 27, 'against': 19}},
#     'away': {'played': 19,
#      'win': 7,
#      'draw': 7,
#      'lose': 5,
#      'goals': {'for': 24, 'against': 21}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 8,
#     'team': {'id': 42,
#      'name': 'Arsenal',
#      'logo': 'https://media.api-sports.io/football/teams/42.png'},
#     'points': 56,
#     'goalsDiff': 8,
#     'group': 'Premier League',
#     'form': 'WLWLD',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 14,
#      'draw': 14,
#      'lose': 10,
#      'goals': {'for': 56, 'against': 48}},
#     'home': {'played': 19,
#      'win': 10,
#      'draw': 6,
#      'lose': 3,
#      'goals': {'for': 36, 'against': 24}},
#     'away': {'played': 19,
#      'win': 4,
#      'draw': 8,
#      'lose': 7,
#      'goals': {'for': 20, 'against': 24}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 9,
#     'team': {'id': 62,
#      'name': 'Sheffield Utd',
#      'logo': 'https://media.api-sports.io/football/teams/62.png'},
#     'points': 54,
#     'goalsDiff': 0,
#     'group': 'Premier League',
#     'form': 'LLLWW',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 14,
#      'draw': 12,
#      'lose': 12,
#      'goals': {'for': 39, 'against': 39}},
#     'home': {'played': 19,
#      'win': 10,
#      'draw': 3,
#      'lose': 6,
#      'goals': {'for': 24, 'against': 15}},
#     'away': {'played': 19,
#      'win': 4,
#      'draw': 9,
#      'lose': 6,
#      'goals': {'for': 15, 'against': 24}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 10,
#     'team': {'id': 44,
#      'name': 'Burnley',
#      'logo': 'https://media.api-sports.io/football/teams/44.png'},
#     'points': 54,
#     'goalsDiff': -7,
#     'group': 'Premier League',
#     'form': 'LWDDW',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 15,
#      'draw': 9,
#      'lose': 14,
#      'goals': {'for': 43, 'against': 50}},
#     'home': {'played': 19,
#      'win': 8,
#      'draw': 4,
#      'lose': 7,
#      'goals': {'for': 24, 'against': 23}},
#     'away': {'played': 19,
#      'win': 7,
#      'draw': 5,
#      'lose': 7,
#      'goals': {'for': 19, 'against': 27}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 11,
#     'team': {'id': 41,
#      'name': 'Southampton',
#      'logo': 'https://media.api-sports.io/football/teams/41.png'},
#     'points': 52,
#     'goalsDiff': -9,
#     'group': 'Premier League',
#     'form': 'WWDDD',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 15,
#      'draw': 7,
#      'lose': 16,
#      'goals': {'for': 51, 'against': 60}},
#     'home': {'played': 19,
#      'win': 6,
#      'draw': 3,
#      'lose': 10,
#      'goals': {'for': 21, 'against': 35}},
#     'away': {'played': 19,
#      'win': 9,
#      'draw': 4,
#      'lose': 6,
#      'goals': {'for': 30, 'against': 25}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 12,
#     'team': {'id': 45,
#      'name': 'Everton',
#      'logo': 'https://media.api-sports.io/football/teams/45.png'},
#     'points': 49,
#     'goalsDiff': -12,
#     'group': 'Premier League',
#     'form': 'LWDLD',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 13,
#      'draw': 10,
#      'lose': 15,
#      'goals': {'for': 44, 'against': 56}},
#     'home': {'played': 19,
#      'win': 8,
#      'draw': 7,
#      'lose': 4,
#      'goals': {'for': 24, 'against': 21}},
#     'away': {'played': 19,
#      'win': 5,
#      'draw': 3,
#      'lose': 11,
#      'goals': {'for': 20, 'against': 35}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 13,
#     'team': {'id': 34,
#      'name': 'Newcastle',
#      'logo': 'https://media.api-sports.io/football/teams/34.png'},
#     'points': 44,
#     'goalsDiff': -20,
#     'group': 'Premier League',
#     'form': 'LDLLL',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 11,
#      'draw': 11,
#      'lose': 16,
#      'goals': {'for': 38, 'against': 58}},
#     'home': {'played': 19,
#      'win': 6,
#      'draw': 8,
#      'lose': 5,
#      'goals': {'for': 20, 'against': 21}},
#     'away': {'played': 19,
#      'win': 5,
#      'draw': 3,
#      'lose': 11,
#      'goals': {'for': 18, 'against': 37}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 14,
#     'team': {'id': 52,
#      'name': 'Crystal Palace',
#      'logo': 'https://media.api-sports.io/football/teams/52.png'},
#     'points': 43,
#     'goalsDiff': -19,
#     'group': 'Premier League',
#     'form': 'DLLLL',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 11,
#      'draw': 10,
#      'lose': 17,
#      'goals': {'for': 31, 'against': 50}},
#     'home': {'played': 19,
#      'win': 6,
#      'draw': 5,
#      'lose': 8,
#      'goals': {'for': 15, 'against': 20}},
#     'away': {'played': 19,
#      'win': 5,
#      'draw': 5,
#      'lose': 9,
#      'goals': {'for': 16, 'against': 30}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 15,
#     'team': {'id': 51,
#      'name': 'Brighton',
#      'logo': 'https://media.api-sports.io/football/teams/51.png'},
#     'points': 41,
#     'goalsDiff': -15,
#     'group': 'Premier League',
#     'form': 'WDDLL',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 9,
#      'draw': 14,
#      'lose': 15,
#      'goals': {'for': 39, 'against': 54}},
#     'home': {'played': 19,
#      'win': 5,
#      'draw': 7,
#      'lose': 7,
#      'goals': {'for': 20, 'against': 27}},
#     'away': {'played': 19,
#      'win': 4,
#      'draw': 7,
#      'lose': 8,
#      'goals': {'for': 19, 'against': 27}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 16,
#     'team': {'id': 48,
#      'name': 'West Ham',
#      'logo': 'https://media.api-sports.io/football/teams/48.png'},
#     'points': 39,
#     'goalsDiff': -13,
#     'group': 'Premier League',
#     'form': 'DDWWL',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 10,
#      'draw': 9,
#      'lose': 19,
#      'goals': {'for': 49, 'against': 62}},
#     'home': {'played': 19,
#      'win': 6,
#      'draw': 4,
#      'lose': 9,
#      'goals': {'for': 30, 'against': 33}},
#     'away': {'played': 19,
#      'win': 4,
#      'draw': 5,
#      'lose': 10,
#      'goals': {'for': 19, 'against': 29}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 17,
#     'team': {'id': 66,
#      'name': 'Aston Villa',
#      'logo': 'https://media.api-sports.io/football/teams/66.png'},
#     'points': 35,
#     'goalsDiff': -26,
#     'group': 'Premier League',
#     'form': 'DWDWL',
#     'status': 'same',
#     'description': None,
#     'all': {'played': 38,
#      'win': 9,
#      'draw': 8,
#      'lose': 21,
#      'goals': {'for': 41, 'against': 67}},
#     'home': {'played': 19,
#      'win': 7,
#      'draw': 3,
#      'lose': 9,
#      'goals': {'for': 22, 'against': 30}},
#     'away': {'played': 19,
#      'win': 2,
#      'draw': 5,
#      'lose': 12,
#      'goals': {'for': 19, 'against': 37}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 18,
#     'team': {'id': 35,
#      'name': 'Bournemouth',
#      'logo': 'https://media.api-sports.io/football/teams/35.png'},
#     'points': 34,
#     'goalsDiff': -25,
#     'group': 'Premier League',
#     'form': 'WLLWD',
#     'status': 'same',
#     'description': 'Relegation - Championship',
#     'all': {'played': 38,
#      'win': 9,
#      'draw': 7,
#      'lose': 22,
#      'goals': {'for': 40, 'against': 65}},
#     'home': {'played': 19,
#      'win': 5,
#      'draw': 6,
#      'lose': 8,
#      'goals': {'for': 22, 'against': 30}},
#     'away': {'played': 19,
#      'win': 4,
#      'draw': 1,
#      'lose': 14,
#      'goals': {'for': 18, 'against': 35}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 19,
#     'team': {'id': 38,
#      'name': 'Watford',
#      'logo': 'https://media.api-sports.io/football/teams/38.png'},
#     'points': 34,
#     'goalsDiff': -28,
#     'group': 'Premier League',
#     'form': 'LLLWW',
#     'status': 'same',
#     'description': 'Relegation - Championship',
#     'all': {'played': 38,
#      'win': 8,
#      'draw': 10,
#      'lose': 20,
#      'goals': {'for': 36, 'against': 64}},
#     'home': {'played': 19,
#      'win': 6,
#      'draw': 6,
#      'lose': 7,
#      'goals': {'for': 22, 'against': 27}},
#     'away': {'played': 19,
#      'win': 2,
#      'draw': 4,
#      'lose': 13,
#      'goals': {'for': 14, 'against': 37}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 20,
#     'team': {'id': 71,
#      'name': 'Norwich',
#      'logo': 'https://media.api-sports.io/football/teams/71.png'},
#     'points': 21,
#     'goalsDiff': -49,
#     'group': 'Premier League',
#     'form': 'LLLLL',
#     'status': 'same',
#     'description': 'Relegation - Championship',
#     'all': {'played': 38,
#      'win': 5,
#      'draw': 6,
#      'lose': 27,
#      'goals': {'for': 26, 'against': 75}},
#     'home': {'played': 19,
#      'win': 4,
#      'draw': 3,
#      'lose': 12,
#      'goals': {'for': 19, 'against': 37}},
#     'away': {'played': 19,
#      'win': 1,
#      'draw': 3,
#      'lose': 15,
#      'goals': {'for': 7, 'against': 38}},
#     'update': '2020-07-26T00:00:00+00:00'}]]}

# %%
df['response'][0]['league']['standings'][0]
# Out:
# [{'rank': 1,
#   'team': {'id': 40,
#    'name': 'Liverpool',
#    'logo': 'https://media.api-sports.io/football/teams/40.png'},
#   'points': 99,
#   'goalsDiff': 52,
#   'group': 'Premier League',
#   'form': 'WWLDW',
#   'status': 'same',
#   'description': 'Promotion - Champions League (Group Stage)',
#   'all': {'played': 38,
#    'win': 32,
#    'draw': 3,
#    'lose': 3,
#    'goals': {'for': 85, 'against': 33}},
#   'home': {'played': 19,
#    'win': 18,
#    'draw': 1,
#    'lose': 0,
#    'goals': {'for': 52, 'against': 16}},
#   'away': {'played': 19,
#    'win': 14,
#    'draw': 2,
#    'lose': 3,
#    'goals': {'for': 33, 'against': 17}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 2,
#   'team': {'id': 50,
#    'name': 'Manchester City',
#    'logo': 'https://media.api-sports.io/football/teams/50.png'},
#   'points': 81,
#   'goalsDiff': 67,
#   'group': 'Premier League',
#   'form': 'WWWWW',
#   'status': 'same',
#   'description': 'Promotion - Champions League (Group Stage)',
#   'all': {'played': 38,
#    'win': 26,
#    'draw': 3,
#    'lose': 9,
#    'goals': {'for': 102, 'against': 35}},
#   'home': {'played': 19,
#    'win': 15,
#    'draw': 2,
#    'lose': 2,
#    'goals': {'for': 57, 'against': 13}},
#   'away': {'played': 19,
#    'win': 11,
#    'draw': 1,
#    'lose': 7,
#    'goals': {'for': 45, 'against': 22}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 3,
#   'team': {'id': 33,
#    'name': 'Manchester United',
#    'logo': 'https://media.api-sports.io/football/teams/33.png'},
#   'points': 66,
#   'goalsDiff': 30,
#   'group': 'Premier League',
#   'form': 'WDWDW',
#   'status': 'same',
#   'description': 'Promotion - Champions League (Group Stage)',
#   'all': {'played': 38,
#    'win': 18,
#    'draw': 12,
#    'lose': 8,
#    'goals': {'for': 66, 'against': 36}},
#   'home': {'played': 19,
#    'win': 10,
#    'draw': 7,
#    'lose': 2,
#    'goals': {'for': 40, 'against': 17}},
#   'away': {'played': 19,
#    'win': 8,
#    'draw': 5,
#    'lose': 6,
#    'goals': {'for': 26, 'against': 19}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 4,
#   'team': {'id': 49,
#    'name': 'Chelsea',
#    'logo': 'https://media.api-sports.io/football/teams/49.png'},
#   'points': 66,
#   'goalsDiff': 15,
#   'group': 'Premier League',
#   'form': 'WLWLW',
#   'status': 'same',
#   'description': 'Promotion - Champions League (Group Stage)',
#   'all': {'played': 38,
#    'win': 20,
#    'draw': 6,
#    'lose': 12,
#    'goals': {'for': 69, 'against': 54}},
#   'home': {'played': 19,
#    'win': 11,
#    'draw': 3,
#    'lose': 5,
#    'goals': {'for': 30, 'against': 16}},
#   'away': {'played': 19,
#    'win': 9,
#    'draw': 3,
#    'lose': 7,
#    'goals': {'for': 39, 'against': 38}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 5,
#   'team': {'id': 46,
#    'name': 'Leicester',
#    'logo': 'https://media.api-sports.io/football/teams/46.png'},
#   'points': 62,
#   'goalsDiff': 26,
#   'group': 'Premier League',
#   'form': 'LLWLD',
#   'status': 'same',
#   'description': 'Promotion - Europa League (Group Stage)',
#   'all': {'played': 38,
#    'win': 18,
#    'draw': 8,
#    'lose': 12,
#    'goals': {'for': 67, 'against': 41}},
#   'home': {'played': 19,
#    'win': 11,
#    'draw': 4,
#    'lose': 4,
#    'goals': {'for': 35, 'against': 17}},
#   'away': {'played': 19,
#    'win': 7,
#    'draw': 4,
#    'lose': 8,
#    'goals': {'for': 32, 'against': 24}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 6,
#   'team': {'id': 47,
#    'name': 'Tottenham',
#    'logo': 'https://media.api-sports.io/football/teams/47.png'},
#   'points': 59,
#   'goalsDiff': 14,
#   'group': 'Premier League',
#   'form': 'DWWWD',
#   'status': 'same',
#   'description': 'Promotion - Europa League (Qualification)',
#   'all': {'played': 38,
#    'win': 16,
#    'draw': 11,
#    'lose': 11,
#    'goals': {'for': 61, 'against': 47}},
#   'home': {'played': 19,
#    'win': 12,
#    'draw': 3,
#    'lose': 4,
#    'goals': {'for': 36, 'against': 17}},
#   'away': {'played': 19,
#    'win': 4,
#    'draw': 8,
#    'lose': 7,
#    'goals': {'for': 25, 'against': 30}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 7,
#   'team': {'id': 39,
#    'name': 'Wolves',
#    'logo': 'https://media.api-sports.io/football/teams/39.png'},
#   'points': 59,
#   'goalsDiff': 11,
#   'group': 'Premier League',
#   'form': 'LWDWL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 15,
#    'draw': 14,
#    'lose': 9,
#    'goals': {'for': 51, 'against': 40}},
#   'home': {'played': 19,
#    'win': 8,
#    'draw': 7,
#    'lose': 4,
#    'goals': {'for': 27, 'against': 19}},
#   'away': {'played': 19,
#    'win': 7,
#    'draw': 7,
#    'lose': 5,
#    'goals': {'for': 24, 'against': 21}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 8,
#   'team': {'id': 42,
#    'name': 'Arsenal',
#    'logo': 'https://media.api-sports.io/football/teams/42.png'},
#   'points': 56,
#   'goalsDiff': 8,
#   'group': 'Premier League',
#   'form': 'WLWLD',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 14,
#    'draw': 14,
#    'lose': 10,
#    'goals': {'for': 56, 'against': 48}},
#   'home': {'played': 19,
#    'win': 10,
#    'draw': 6,
#    'lose': 3,
#    'goals': {'for': 36, 'against': 24}},
#   'away': {'played': 19,
#    'win': 4,
#    'draw': 8,
#    'lose': 7,
#    'goals': {'for': 20, 'against': 24}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 9,
#   'team': {'id': 62,
#    'name': 'Sheffield Utd',
#    'logo': 'https://media.api-sports.io/football/teams/62.png'},
#   'points': 54,
#   'goalsDiff': 0,
#   'group': 'Premier League',
#   'form': 'LLLWW',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 14,
#    'draw': 12,
#    'lose': 12,
#    'goals': {'for': 39, 'against': 39}},
#   'home': {'played': 19,
#    'win': 10,
#    'draw': 3,
#    'lose': 6,
#    'goals': {'for': 24, 'against': 15}},
#   'away': {'played': 19,
#    'win': 4,
#    'draw': 9,
#    'lose': 6,
#    'goals': {'for': 15, 'against': 24}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 10,
#   'team': {'id': 44,
#    'name': 'Burnley',
#    'logo': 'https://media.api-sports.io/football/teams/44.png'},
#   'points': 54,
#   'goalsDiff': -7,
#   'group': 'Premier League',
#   'form': 'LWDDW',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 15,
#    'draw': 9,
#    'lose': 14,
#    'goals': {'for': 43, 'against': 50}},
#   'home': {'played': 19,
#    'win': 8,
#    'draw': 4,
#    'lose': 7,
#    'goals': {'for': 24, 'against': 23}},
#   'away': {'played': 19,
#    'win': 7,
#    'draw': 5,
#    'lose': 7,
#    'goals': {'for': 19, 'against': 27}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 11,
#   'team': {'id': 41,
#    'name': 'Southampton',
#    'logo': 'https://media.api-sports.io/football/teams/41.png'},
#   'points': 52,
#   'goalsDiff': -9,
#   'group': 'Premier League',
#   'form': 'WWDDD',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 15,
#    'draw': 7,
#    'lose': 16,
#    'goals': {'for': 51, 'against': 60}},
#   'home': {'played': 19,
#    'win': 6,
#    'draw': 3,
#    'lose': 10,
#    'goals': {'for': 21, 'against': 35}},
#   'away': {'played': 19,
#    'win': 9,
#    'draw': 4,
#    'lose': 6,
#    'goals': {'for': 30, 'against': 25}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 12,
#   'team': {'id': 45,
#    'name': 'Everton',
#    'logo': 'https://media.api-sports.io/football/teams/45.png'},
#   'points': 49,
#   'goalsDiff': -12,
#   'group': 'Premier League',
#   'form': 'LWDLD',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 13,
#    'draw': 10,
#    'lose': 15,
#    'goals': {'for': 44, 'against': 56}},
#   'home': {'played': 19,
#    'win': 8,
#    'draw': 7,
#    'lose': 4,
#    'goals': {'for': 24, 'against': 21}},
#   'away': {'played': 19,
#    'win': 5,
#    'draw': 3,
#    'lose': 11,
#    'goals': {'for': 20, 'against': 35}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 13,
#   'team': {'id': 34,
#    'name': 'Newcastle',
#    'logo': 'https://media.api-sports.io/football/teams/34.png'},
#   'points': 44,
#   'goalsDiff': -20,
#   'group': 'Premier League',
#   'form': 'LDLLL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 11,
#    'draw': 11,
#    'lose': 16,
#    'goals': {'for': 38, 'against': 58}},
#   'home': {'played': 19,
#    'win': 6,
#    'draw': 8,
#    'lose': 5,
#    'goals': {'for': 20, 'against': 21}},
#   'away': {'played': 19,
#    'win': 5,
#    'draw': 3,
#    'lose': 11,
#    'goals': {'for': 18, 'against': 37}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 14,
#   'team': {'id': 52,
#    'name': 'Crystal Palace',
#    'logo': 'https://media.api-sports.io/football/teams/52.png'},
#   'points': 43,
#   'goalsDiff': -19,
#   'group': 'Premier League',
#   'form': 'DLLLL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 11,
#    'draw': 10,
#    'lose': 17,
#    'goals': {'for': 31, 'against': 50}},
#   'home': {'played': 19,
#    'win': 6,
#    'draw': 5,
#    'lose': 8,
#    'goals': {'for': 15, 'against': 20}},
#   'away': {'played': 19,
#    'win': 5,
#    'draw': 5,
#    'lose': 9,
#    'goals': {'for': 16, 'against': 30}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 15,
#   'team': {'id': 51,
#    'name': 'Brighton',
#    'logo': 'https://media.api-sports.io/football/teams/51.png'},
#   'points': 41,
#   'goalsDiff': -15,
#   'group': 'Premier League',
#   'form': 'WDDLL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 9,
#    'draw': 14,
#    'lose': 15,
#    'goals': {'for': 39, 'against': 54}},
#   'home': {'played': 19,
#    'win': 5,
#    'draw': 7,
#    'lose': 7,
#    'goals': {'for': 20, 'against': 27}},
#   'away': {'played': 19,
#    'win': 4,
#    'draw': 7,
#    'lose': 8,
#    'goals': {'for': 19, 'against': 27}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 16,
#   'team': {'id': 48,
#    'name': 'West Ham',
#    'logo': 'https://media.api-sports.io/football/teams/48.png'},
#   'points': 39,
#   'goalsDiff': -13,
#   'group': 'Premier League',
#   'form': 'DDWWL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 10,
#    'draw': 9,
#    'lose': 19,
#    'goals': {'for': 49, 'against': 62}},
#   'home': {'played': 19,
#    'win': 6,
#    'draw': 4,
#    'lose': 9,
#    'goals': {'for': 30, 'against': 33}},
#   'away': {'played': 19,
#    'win': 4,
#    'draw': 5,
#    'lose': 10,
#    'goals': {'for': 19, 'against': 29}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 17,
#   'team': {'id': 66,
#    'name': 'Aston Villa',
#    'logo': 'https://media.api-sports.io/football/teams/66.png'},
#   'points': 35,
#   'goalsDiff': -26,
#   'group': 'Premier League',
#   'form': 'DWDWL',
#   'status': 'same',
#   'description': None,
#   'all': {'played': 38,
#    'win': 9,
#    'draw': 8,
#    'lose': 21,
#    'goals': {'for': 41, 'against': 67}},
#   'home': {'played': 19,
#    'win': 7,
#    'draw': 3,
#    'lose': 9,
#    'goals': {'for': 22, 'against': 30}},
#   'away': {'played': 19,
#    'win': 2,
#    'draw': 5,
#    'lose': 12,
#    'goals': {'for': 19, 'against': 37}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 18,
#   'team': {'id': 35,
#    'name': 'Bournemouth',
#    'logo': 'https://media.api-sports.io/football/teams/35.png'},
#   'points': 34,
#   'goalsDiff': -25,
#   'group': 'Premier League',
#   'form': 'WLLWD',
#   'status': 'same',
#   'description': 'Relegation - Championship',
#   'all': {'played': 38,
#    'win': 9,
#    'draw': 7,
#    'lose': 22,
#    'goals': {'for': 40, 'against': 65}},
#   'home': {'played': 19,
#    'win': 5,
#    'draw': 6,
#    'lose': 8,
#    'goals': {'for': 22, 'against': 30}},
#   'away': {'played': 19,
#    'win': 4,
#    'draw': 1,
#    'lose': 14,
#    'goals': {'for': 18, 'against': 35}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 19,
#   'team': {'id': 38,
#    'name': 'Watford',
#    'logo': 'https://media.api-sports.io/football/teams/38.png'},
#   'points': 34,
#   'goalsDiff': -28,
#   'group': 'Premier League',
#   'form': 'LLLWW',
#   'status': 'same',
#   'description': 'Relegation - Championship',
#   'all': {'played': 38,
#    'win': 8,
#    'draw': 10,
#    'lose': 20,
#    'goals': {'for': 36, 'against': 64}},
#   'home': {'played': 19,
#    'win': 6,
#    'draw': 6,
#    'lose': 7,
#    'goals': {'for': 22, 'against': 27}},
#   'away': {'played': 19,
#    'win': 2,
#    'draw': 4,
#    'lose': 13,
#    'goals': {'for': 14, 'against': 37}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 20,
#   'team': {'id': 71,
#    'name': 'Norwich',
#    'logo': 'https://media.api-sports.io/football/teams/71.png'},
#   'points': 21,
#   'goalsDiff': -49,
#   'group': 'Premier League',
#   'form': 'LLLLL',
#   'status': 'same',
#   'description': 'Relegation - Championship',
#   'all': {'played': 38,
#    'win': 5,
#    'draw': 6,
#    'lose': 27,
#    'goals': {'for': 26, 'against': 75}},
#   'home': {'played': 19,
#    'win': 4,
#    'draw': 3,
#    'lose': 12,
#    'goals': {'for': 19, 'against': 37}},
#   'away': {'played': 19,
#    'win': 1,
#    'draw': 3,
#    'lose': 15,
#    'goals': {'for': 7, 'against': 38}},
#   'update': '2020-07-26T00:00:00+00:00'}]

# %%
df['response'][0]['league'].keys()
# Out:
# dict_keys(['id', 'name', 'country', 'logo', 'flag', 'season', 'standings'])

# %%
df['response'][0]['league']['standings'][0][0].keys()
# Out:
# dict_keys(['rank', 'team', 'points', 'goalsDiff', 'group', 'form', 'status', 'description', 'all', 'home', 'away', 'update'])

# %%
df['response'][0]['league']['standings'][0][0]['update']
# Out:
# '2020-07-26T00:00:00+00:00'

# %%
while True:
    # main program
    while True:
        answer = str(input('Run again? (y/n): '))
        if answer in ('y', 'n'):
            break
        print("invalid input.")
    if answer == 'y':
        continue
    else:
        print("Goodbye")
        break
# Out:
# Run again? (y/n): n
# Goodbye

# %%
import requests

url = "https://livescore6.p.rapidapi.com/matches/v2/get-scoreboard"

querystring = {"Eid":"702093","Category":"soccer"}

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "livescore6.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print (type(response.json()))
print(response.json())
df = response.json()
# Out:
# <class 'dict'>
# {'Eid': '702093', 'Pids': {'32': '2699489', '1': '3901012', '6': '34151847', '8': '702093', '12': 'SBTE_27476152', '28': '1210119345', '30': 'c6677013-214b-4459-81f0-68ec91c51394'}, 'Sids': {'32': '18118', '1': '879290', '6': '65927', '8': '10765', '28': '1209617720', '12': 'SBTC3_40253', '30': '855adaf5-49f3-4887-b304-dfb8be78fdbb'}, 'Media': {'32': [{'ageRestricted': 'false', 'articleId': '2022100113224853898', 'type': 'RESULT'}], '12': [{'eventId': 'BT Sport 1', 'provider': 'ABELSON', 'allowedCountries': ['GB', 'IE'], 'type': 'TV_CHANNEL'}, {'eventId': 'Viaplay', 'provider': 'ABELSON', 'allowedCountries': ['NL'], 'type': 'TV_CHANNEL'}]}, 'Tr1': '3', 'Tr2': '1', 'Trh1': '1', 'Trh2': '1', 'Tr1OR': '3', 'Tr2OR': '1', 'T1': [{'Nm': 'Arsenal', 'ID': '2773', 'Img': 'enet/9825.png', 'NewsTag': '/team/arsenal-2021020913320920836-97/', 'Abr': 'ARS', 'tbd': 0, 'Gd': 1, 'Pids': {'32': ['97'], '1': ['9825'], '6': ['42'], '8': ['2773'], '28': ['23429'], '12': ['SBTP_248'], '30': ['40c7eb19-93d7-4c1a-a8b2-1cfc40bc2454'], '15': ['4']}, 'CoNm': 'England', 'CoId': 'GBR', 'HasVideo': True}], 'T2': [{'Nm': 'Tottenham Hotspur', 'ID': '3339', 'Img': 'enet/8586.png', 'NewsTag': '/team/tottenham-2021020913320920836-89/', 'Abr': 'TOT', 'tbd': 0, 'Gd': 1, 'Pids': {'32': ['89'], '1': ['8586'], '6': ['33'], '8': ['3339'], '28': ['7760'], '12': ['SBTP_242'], '30': ['addf0d43-f862-4023-90a9-bb7e1318c43a'], '15': ['18']}, 'CoNm': 'England', 'CoId': 'GBR', 'HasVideo': True}], 'Eps': 'FT', 'Esid': 6, 'Epr': 2, 'Ecov': 0, 'Ern': 9, 'ErnInf': '9', 'Ewt': 1, 'Et': 1, 'Esd': 20221001113000, 'LuUT': 20221004062943, 'Edf': 20221001132125, 'Eact': 0, 'EO': 27247485, 'LuC': 1, 'Ehid': 0, 'Spid': 1, 'Stg': {'Sid': '10765', 'Snm': 'Premier League', 'Scd': 'premier-league', 'Cid': '34', 'Cnm': 'England', 'Csnm': 'England', 'Ccd': 'england', 'CompId': '65', 'CompN': 'Premier League', 'CompD': 'England', 'CompST': 'England', 'Scu': 0, 'Sds': 'Premier League', 'Ccdiso': 'GBR', 'Chi': 0, 'Shi': 0, 'Sdn': 'Premier League'}, 'Pid': 8, 'Eloff': 0, 'Incs-s': {'1': [{'Min': 20, 'Nm': 1, 'Sc': [1, 0], 'Sor': 1, 'Incs': [{'Min': 20, 'Nm': 1, 'PosA': 3, 'Aid': '31016', 'ID': '31016', 'Fn': 'Thomas', 'Ln': 'Partey', 'Pnum': 0, 'Pn': 'Thomas Partey', 'PnumO': 0, 'IT': 36, 'Sc': [1, 0], 'Sor': 1}]}, {'Min': 31, 'Nm': 2, 'PosA': 4, 'Aid': '26051', 'ID': '26051', 'Fn': 'Harry', 'Ln': 'Kane', 'Pnum': 0, 'Pn': 'Harry Kane', 'PnumO': 0, 'IT': 37, 'Sc': [1, 1], 'Sor': 0}], '2': [{'Min': 49, 'Nm': 1, 'PosA': 4, 'Aid': '3253', 'ID': '3253', 'Fn': 'Gabriel', 'Ln': 'Jesus', 'Pnum': 0, 'Pn': 'Gabriel Jesus', 'PnumO': 0, 'IT': 36, 'Sc': [2, 1], 'Sor': 1}, {'Min': 62, 'Nm': 2, 'PosA': 2, 'Aid': '26070', 'ID': '26070', 'Ln': 'Emerson', 'Snm': 'Emerson', 'Pnum': 0, 'Pn': 'Emerson Royal', 'PnumO': 0, 'IT': 45, 'Sor': 2}, {'Min': 67, 'Nm': 1, 'Sc': [3, 1], 'Sor': 1, 'Incs': [{'Min': 67, 'Nm': 1, 'PosA': 3, 'Aid': '31014', 'ID': '31014', 'Fn': 'Granit', 'Ln': 'Xhaka', 'Pnum': 0, 'Pn': 'Granit Xhaka', 'PnumO': 0, 'IT': 36, 'Sc': [3, 1], 'Sor': 1}]}]}}

# %%
df
# Out:
# {'Eid': '702093',
#  'Pids': {'32': '2699489',
#   '1': '3901012',
#   '6': '34151847',
#   '8': '702093',
#   '12': 'SBTE_27476152',
#   '28': '1210119345',
#   '30': 'c6677013-214b-4459-81f0-68ec91c51394'},
#  'Sids': {'32': '18118',
#   '1': '879290',
#   '6': '65927',
#   '8': '10765',
#   '28': '1209617720',
#   '12': 'SBTC3_40253',
#   '30': '855adaf5-49f3-4887-b304-dfb8be78fdbb'},
#  'Media': {'32': [{'ageRestricted': 'false',
#     'articleId': '2022100113224853898',
#     'type': 'RESULT'}],
#   '12': [{'eventId': 'BT Sport 1',
#     'provider': 'ABELSON',
#     'allowedCountries': ['GB', 'IE'],
#     'type': 'TV_CHANNEL'},
#    {'eventId': 'Viaplay',
#     'provider': 'ABELSON',
#     'allowedCountries': ['NL'],
#     'type': 'TV_CHANNEL'}]},
#  'Tr1': '3',
#  'Tr2': '1',
#  'Trh1': '1',
#  'Trh2': '1',
#  'Tr1OR': '3',
#  'Tr2OR': '1',
#  'T1': [{'Nm': 'Arsenal',
#    'ID': '2773',
#    'Img': 'enet/9825.png',
#    'NewsTag': '/team/arsenal-2021020913320920836-97/',
#    'Abr': 'ARS',
#    'tbd': 0,
#    'Gd': 1,
#    'Pids': {'32': ['97'],
#     '1': ['9825'],
#     '6': ['42'],
#     '8': ['2773'],
#     '28': ['23429'],
#     '12': ['SBTP_248'],
#     '30': ['40c7eb19-93d7-4c1a-a8b2-1cfc40bc2454'],
#     '15': ['4']},
#    'CoNm': 'England',
#    'CoId': 'GBR',
#    'HasVideo': True}],
#  'T2': [{'Nm': 'Tottenham Hotspur',
#    'ID': '3339',
#    'Img': 'enet/8586.png',
#    'NewsTag': '/team/tottenham-2021020913320920836-89/',
#    'Abr': 'TOT',
#    'tbd': 0,
#    'Gd': 1,
#    'Pids': {'32': ['89'],
#     '1': ['8586'],
#     '6': ['33'],
#     '8': ['3339'],
#     '28': ['7760'],
#     '12': ['SBTP_242'],
#     '30': ['addf0d43-f862-4023-90a9-bb7e1318c43a'],
#     '15': ['18']},
#    'CoNm': 'England',
#    'CoId': 'GBR',
#    'HasVideo': True}],
#  'Eps': 'FT',
#  'Esid': 6,
#  'Epr': 2,
#  'Ecov': 0,
#  'Ern': 9,
#  'ErnInf': '9',
#  'Ewt': 1,
#  'Et': 1,
#  'Esd': 20221001113000,
#  'LuUT': 20221004062943,
#  'Edf': 20221001132125,
#  'Eact': 0,
#  'EO': 27247485,
#  'LuC': 1,
#  'Ehid': 0,
#  'Spid': 1,
#  'Stg': {'Sid': '10765',
#   'Snm': 'Premier League',
#   'Scd': 'premier-league',
#   'Cid': '34',
#   'Cnm': 'England',
#   'Csnm': 'England',
#   'Ccd': 'england',
#   'CompId': '65',
#   'CompN': 'Premier League',
#   'CompD': 'England',
#   'CompST': 'England',
#   'Scu': 0,
#   'Sds': 'Premier League',
#   'Ccdiso': 'GBR',
#   'Chi': 0,
#   'Shi': 0,
#   'Sdn': 'Premier League'},
#  'Pid': 8,
#  'Eloff': 0,
#  'Incs-s': {'1': [{'Min': 20,
#     'Nm': 1,
#     'Sc': [1, 0],
#     'Sor': 1,
#     'Incs': [{'Min': 20,
#       'Nm': 1,
#       'PosA': 3,
#       'Aid': '31016',
#       'ID': '31016',
#       'Fn': 'Thomas',
#       'Ln': 'Partey',
#       'Pnum': 0,
#       'Pn': 'Thomas Partey',
#       'PnumO': 0,
#       'IT': 36,
#       'Sc': [1, 0],
#       'Sor': 1}]},
#    {'Min': 31,
#     'Nm': 2,
#     'PosA': 4,
#     'Aid': '26051',
#     'ID': '26051',
#     'Fn': 'Harry',
#     'Ln': 'Kane',
#     'Pnum': 0,
#     'Pn': 'Harry Kane',
#     'PnumO': 0,
#     'IT': 37,
#     'Sc': [1, 1],
#     'Sor': 0}],
#   '2': [{'Min': 49,
#     'Nm': 1,
#     'PosA': 4,
#     'Aid': '3253',
#     'ID': '3253',
#     'Fn': 'Gabriel',
#     'Ln': 'Jesus',
#     'Pnum': 0,
#     'Pn': 'Gabriel Jesus',
#     'PnumO': 0,
#     'IT': 36,
#     'Sc': [2, 1],
#     'Sor': 1},
#    {'Min': 62,
#     'Nm': 2,
#     'PosA': 2,
#     'Aid': '26070',
#     'ID': '26070',
#     'Ln': 'Emerson',
#     'Snm': 'Emerson',
#     'Pnum': 0,
#     'Pn': 'Emerson Royal',
#     'PnumO': 0,
#     'IT': 45,
#     'Sor': 2},
#    {'Min': 67,
#     'Nm': 1,
#     'Sc': [3, 1],
#     'Sor': 1,
#     'Incs': [{'Min': 67,
#       'Nm': 1,
#       'PosA': 3,
#       'Aid': '31014',
#       'ID': '31014',
#       'Fn': 'Granit',
#       'Ln': 'Xhaka',
#       'Pnum': 0,
#       'Pn': 'Granit Xhaka',
#       'PnumO': 0,
#       'IT': 36,
#       'Sc': [3, 1],
#       'Sor': 1}]}]}}

# %%
df.keys()
# Out:
# dict_keys(['Eid', 'Pids', 'Sids', 'Media', 'Tr1', 'Tr2', 'Trh1', 'Trh2', 'Tr1OR', 'Tr2OR', 'T1', 'T2', 'Eps', 'Esid', 'Epr', 'Ecov', 'Ern', 'ErnInf', 'Ewt', 'Et', 'Esd', 'LuUT', 'Edf', 'Eact', 'EO', 'LuC', 'Ehid', 'Spid', 'Stg', 'Pid', 'Eloff', 'Incs-s'])

# %%
df['Pids']
# Out:
# {'32': '2699489',
#  '1': '3901012',
#  '6': '34151847',
#  '8': '702093',
#  '12': 'SBTE_27476152',
#  '28': '1210119345',
#  '30': 'c6677013-214b-4459-81f0-68ec91c51394'}

# %%
import requests

url = "https://football-betting-odds1.p.rapidapi.com/provider1/live/inplaying"

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "football-betting-odds1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print (type(response.json()))
print(response.json())
df = response.json()
# Out:
# <class 'dict'>
# {'1411131116131109': {'mid': '1411131116131109', 'home': 'Hapoel Petah Tikva FC', 'away': 'Hapoel Acre FC', 'country_leagues': 'Israel - National League', 'leagues': 'National League', 'country': 'Israel', 'score': '0-0', 'home_score': 0, 'away_score': 0, 'periodID': '2', 'periodTXT': 'HalfTime', 'periodTime': 1668445271, 'startTime': 1668445200, 'lastUpdateTime': 1668448849, 'minutes': 1, 'status': '1', 'importancy': 12, 'odds': {'home': '2.45', 'draw': '2.15', 'away': '3.50', '2nd-1': '2.45', '2nd-0': '2.15', '2nd-2': '3.50', 'both-team-score-yes': '3.56', 'both-team-score-no': '1.20', 'double-chance-1-0': '1.22', 'double-chance-0-2': '1.43', 'double-chance-1-2': '1.55', 'draw-refund-1': '1.52', 'draw-refund-2': '2.20', 'total-goal-0': '2.61', 'total-goal-1': '2.25', 'total-goal-2': '3.33', 'total-goal-3': '6.53', 'total-goal-0-1': '1.44', 'total-goal-2-3': '2.43', 'total-goal-4+': '12.15', 'total-goal-0-2': '1.10', 'total-goal-3-4': '5.18', 'total-goal-0-3': '1.01', 'total-goal-4-5': '12.60', 'next-goal-1-1': '2.04', 'next-goal-1-0': '2.76', 'next-goal-1-2': '2.71', '1-hcap-1--1': '6.08', '1-hcap-0--1': '3.06', '1-hcap-2-+1': '1.43', '1-hcap-1-+1': '1.22', '1-hcap-0-+1': '4.05', '1-hcap-2--1': '9.90', 'over-2-5': '5.50', 'under-2-5': '1.10', 'over-1-5': '2.40', 'under-1-5': '1.44', 'over-3-5': '13.50', 'under-3-5': '1.01', 'over-0-5': '1.31', 'under-0-5': '2.90', '2nd-over-1-5': '2.40', '2nd-under-1-5': '1.44', '2nd-over-0-5': '1.31', '2nd-under-0-5': '2.90', '2nd-over-2-5': '5.50', '2nd-under-2-5': '1.10', 'away-total-goal-0': '1.55', 'away-total-goal-1': '2.48', 'away-total-goal-2': '7.43', 'home-total-goal-0': '1.67', 'home-total-goal-1': '2.25', 'home-total-goal-2': '5.18', 'home-total-goal-3+': '12.60', 'away-over-0-5': '2.15', 'away-under-0-5': '1.55', 'away-over-1-5': '7.00', 'away-under-1-5': '1.07', 'home-over-1-5': '4.75', 'home-under-1-5': '1.14', 'home-over-0-5': '1.75', 'home-under-0-5': '1.85', 'home-over-2-5': '14.00', 'home-under-2-5': '1.01', 'rest-of-match-1': '2.45', 'rest-of-match-0': '2.15', 'rest-of-match-2': '3.50'}}, '1411138799131115': {'mid': '1411138799131115', 'home': 'Hapoel Kfar Saba FC', 'away': 'Hapoel Nof Hagalil FC', 'country_leagues': 'Israel - National League', 'leagues': 'National League', 'country': 'Israel', 'score': '0-0', 'home_score': 0, 'away_score': 0, 'periodID': '2', 'periodTXT': 'HalfTime', 'periodTime': 1668445192, 'startTime': 1668445200, 'lastUpdateTime': 1668448849, 'minutes': 1, 'status': '1', 'importancy': 14, 'odds': {'home': '2.10', 'draw': '2.37', 'away': '3.75', '2nd-1': '2.10', '2nd-0': '2.37', '2nd-2': '3.75', 'both-team-score-yes': '2.95', 'both-team-score-no': '1.29', 'double-chance-1-0': '1.20', 'double-chance-0-2': '1.57', 'double-chance-1-2': '1.46', 'draw-refund-1': '1.41', 'draw-refund-2': '2.50', 'total-goal-0': '3.24', 'total-goal-1': '2.39', 'total-goal-2': '2.97', 'total-goal-3': '5.18', 'total-goal-4': '10.80', 'total-goal-0-1': '1.65', 'total-goal-2-3': '2.07', 'total-goal-4+': '8.33', 'total-goal-0-2': '1.18', 'total-goal-3-4': '3.96', 'total-goal-0-3': '1.04', 'total-goal-4-5': '8.78', 'next-goal-1-1': '1.79', 'next-goal-1-0': '3.42', 'next-goal-1-2': '2.73', '1-hcap-1--1': '4.50', '1-hcap-0--1': '2.88', '1-hcap-2-+1': '1.57', '1-hcap-1-+1': '1.20', '1-hcap-0-+1': '4.32', '1-hcap-2--1': '9.90', 'over-2-5': '4.00', 'under-2-5': '1.18', 'over-1-5': '1.98', 'under-1-5': '1.65', 'over-3-5': '9.25', 'under-3-5': '1.04', 'over-0-5': '1.22', 'under-0-5': '3.60', '2nd-over-1-5': '1.98', '2nd-under-1-5': '1.65', '2nd-over-0-5': '1.22', '2nd-under-0-5': '3.60', '2nd-over-2-5': '4.00', '2nd-under-2-5': '1.18', 'away-total-goal-0': '1.63', 'away-total-goal-1': '2.39', 'away-total-goal-2': '6.53', 'home-total-goal-0': '1.98', 'home-total-goal-1': '2.16', 'home-total-goal-2': '4.14', 'home-total-goal-3+': '8.55', 'away-over-0-5': '2.00', 'away-under-0-5': '1.63', 'away-over-1-5': '6.00', 'away-under-1-5': '1.08', 'home-over-1-5': '3.50', 'home-under-1-5': '1.23', ' ...

# %%
df
# Out:
# {'1411131116131109': {'mid': '1411131116131109',
#   'home': 'Hapoel Petah Tikva FC',
#   'away': 'Hapoel Acre FC',
#   'country_leagues': 'Israel - National League',
#   'leagues': 'National League',
#   'country': 'Israel',
#   'score': '0-0',
#   'home_score': 0,
#   'away_score': 0,
#   'periodID': '2',
#   'periodTXT': 'HalfTime',
#   'periodTime': 1668445271,
#   'startTime': 1668445200,
#   'lastUpdateTime': 1668448849,
#   'minutes': 1,
#   'status': '1',
#   'importancy': 12,
#   'odds': {'home': '2.45',
#    'draw': '2.15',
#    'away': '3.50',
#    '2nd-1': '2.45',
#    '2nd-0': '2.15',
#    '2nd-2': '3.50',
#    'both-team-score-yes': '3.56',
#    'both-team-score-no': '1.20',
#    'double-chance-1-0': '1.22',
#    'double-chance-0-2': '1.43',
#    'double-chance-1-2': '1.55',
#    'draw-refund-1': '1.52',
#    'draw-refund-2': '2.20',
#    'total-goal-0': '2.61',
#    'total-goal-1': '2.25',
#    'total-goal-2': '3.33',
#    'total-goal-3': '6.53',
#    'total-goal-0-1': '1.44',
#    'total-goal-2-3': '2.43',
#    'total-goal-4+': '12.15',
#    'total-goal-0-2': '1.10',
#    'total-goal-3-4': '5.18',
#    'total-goal-0-3': '1.01',
#    'total-goal-4-5': '12.60',
#    'next-goal-1-1': '2.04',
#    'next-goal-1-0': '2.76',
#    'next-goal-1-2': '2.71',
#    '1-hcap-1--1': '6.08',
#    '1-hcap-0--1': '3.06',
#    '1-hcap-2-+1': '1.43',
#    '1-hcap-1-+1': '1.22',
#    '1-hcap-0-+1': '4.05',
#    '1-hcap-2--1': '9.90',
#    'over-2-5': '5.50',
#    'under-2-5': '1.10',
#    'over-1-5': '2.40',
#    'under-1-5': '1.44',
#    'over-3-5': '13.50',
#    'under-3-5': '1.01',
#    'over-0-5': '1.31',
#    'under-0-5': '2.90',
#    '2nd-over-1-5': '2.40',
#    '2nd-under-1-5': '1.44',
#    '2nd-over-0-5': '1.31',
#    '2nd-under-0-5': '2.90',
#    '2nd-over-2-5': '5.50',
#    '2nd-under-2-5': '1.10',
#    'away-total-goal-0': '1.55',
#    'away-total-goal-1': '2.48',
#    'away-total-goal-2': '7.43',
#    'home-total-goal-0': '1.67',
#    'home-total-goal-1': '2.25',
#    'home-total-goal-2': '5.18',
#    'home-total-goal-3+': '12.60',
#    'away-over-0-5': '2.15',
#    'away-under-0-5': '1.55',
#    'away-over-1-5': '7.00',
#    'away-under-1-5': '1.07',
#    'home-over-1-5': '4.75',
#    'home-under-1-5': '1.14',
#    'home-over-0-5': '1.75',
#    'home-under-0-5': '1.85',
#    'home-over-2-5': '14.00',
#    'home-under-2-5': '1.01',
#    'rest-of-match-1': '2.45',
#    'rest-of-match-0': '2.15',
#    'rest-of-match-2': '3.50'}},
#  '1411138799131115': {'mid': '1411138799131115',
#   'home': 'Hapoel Kfar Saba FC',
#   'away': 'Hapoel Nof Hagalil FC',
#   'country_leagues': 'Israel - National League',
#   'leagues': 'National League',
#   'country': 'Israel',
#   'score': '0-0',
#   'home_score': 0,
#   'away_score': 0,
#   'periodID': '2',
#   'periodTXT': 'HalfTime',
#   'periodTime': 1668445192,
#   'startTime': 1668445200,
#   'lastUpdateTime': 1668448849,
#   'minutes': 1,
#   'status': '1',
#   'importancy': 14,
#   'odds': {'home': '2.10',
#    'draw': '2.37',
#    'away': '3.75',
#    '2nd-1': '2.10',
#    '2nd-0': '2.37',
#    '2nd-2': '3.75',
#    'both-team-score-yes': '2.95',
#    'both-team-score-no': '1.29',
#    'double-chance-1-0': '1.20',
#    'double-chance-0-2': '1.57',
#    'double-chance-1-2': '1.46',
#    'draw-refund-1': '1.41',
#    'draw-refund-2': '2.50',
#    'total-goal-0': '3.24',
#    'total-goal-1': '2.39',
#    'total-goal-2': '2.97',
#    'total-goal-3': '5.18',
#    'total-goal-4': '10.80',
#    'total-goal-0-1': '1.65',
#    'total-goal-2-3': '2.07',
#    'total-goal-4+': '8.33',
#    'total-goal-0-2': '1.18',
#    'total-goal-3-4': '3.96',
#    'total-goal-0-3': '1.04',
#    'total-goal-4-5': '8.78',
#    'next-goal-1-1': '1.79',
#    'next-goal-1-0': '3.42',
#    'next-goal-1-2': '2.73',
#    '1-hcap-1--1': '4.50',
#    '1-hcap-0--1': '2.88',
#    '1-hcap-2-+1': '1.57',
#    '1-hcap-1-+1': '1.20',
#    '1-hcap-0-+1': '4.32',
#    '1-hcap-2--1': '9.90',
#    'over-2-5': '4.00',
#    'under-2-5': '1.18',
#    'over-1-5': '1.98',
#    'under-1-5': '1.65',
#    'over-3-5': '9.25',
#    'under-3-5': '1.04',
#    'over-0-5': '1.22',
#    'under-0-5': '3.60',
#    '2nd-over-1-5': '1.98',
#    '2nd-under-1-5': '1.65',
#    '2nd-over-0-5': '1.22',
#    '2nd-under-0-5': '3.60',
#    '2nd-over-2-5': '4.00',
#    '2nd-under-2-5': '1.18',
#    'away-total-goal-0': '1.63',
#    'away-total-goal-1': '2.39',
#    'away-total-goal-2': '6.53',
#    'home-total-goal-0': '1.98',
#    'home-total-goal-1': '2.16',
#    'home-total-goal-2': '4.14',
#    'home-total-goal-3+': '8.55',
#    'away-over-0-5': '2.00',
#    'away-under-0-5': '1.63',
#    'away-over-1-5': '6.00',
#    'away-under-1-5': '1.08',
#    'home-over-1-5': '3.50',
#    'home-under-1-5': '1.23',
#    'home-over-0-5': '1.52',
#    'home-under-0-5': '2.20',
#    'home-over-2-5': '9.50',
#    'home-under-2-5': '1.04',
#    'rest-of-match-1': '2.10',
#    'rest-of-match-0': '2.37',
#    'rest-of-match-2': '3.75'}},
#  '1411160050131118': {'mid': '1411160050131118',
#   'home': 'Hapoel Umm al-Fahm',
#   'away': 'Hapoel Rishon Lezion FC',
#   'country_leagues': 'Israel - National League',
#   'leagues': 'National League',
#   'country': 'Israel',
#   'score': '1-0',
#   'home_score': 1,
#   'away_score': 0,
#   'periodID': '2',
#   'periodTXT': 'HalfTime',
#   'periodTime': 1668445194,
#   'startTime': 1668445200,
#   'lastUpdateTime': 1668448849,
#   'minutes': 1,
#   'status': '1',
#   'importancy': 13,
#   'odds': {'home': '1.25',
#    'draw': '4.20',
#    'away': '10.50',
#    '2nd-1': '2.35',
#    '2nd-0': '2.30',
#    '2nd-2': '3.30',
#    'both-team-score-yes': '1.88',
#    'both-team-score-no': '1.66',
#    'double-chance-1-0': '1.03',
#    'double-chance-0-2': '2.97',
#    'double-chance-1-2': '1.16',
#    'draw-refund-1': '1.04',
#    'draw-refund-2': '9.00',
#    'total-goal-1': '3.06',
#    'total-goal-2': '2.25',
#    'total-goal-3': '3.06',
#    'total-goal-4': '5.85',
#    'total-goal-5': '12.60',
#    'total-goal-0-1': '3.06',
#    'total-goal-2-3': '1.55',
#    'total-goal-4+': '4.14',
#    'total-goal-0-2': '1.55',
#    'total-goal-3-4': '2.21',
#    'total-goal-5+': '9.90',
#    'total-goal-0-3': '1.14',
#    'total-goal-4-5': '4.50',
#    '1-hcap-1--1': '2.12',
#    '1-hcap-0--1': '2.07',
#    '1-hcap-2-+1': '2.97',
#    '1-hcap-1--2': '5.18',
#    '1-hcap-0--2': '3.06',
#    '1-hcap-2-+2': '1.47',
#    'over-2-5': '2.15',
#    'under-2-5': '1.55',
#    'over-1-5': '1.24',
#    'under-1-5': '3.40',
#    'over-3-5': '4.60',
#    'under-3-5': '1.14',
#    'over-4-5': '11.00',
#    'under-4-5': '1.02',
#    '2nd-over-1-5': '2.15',
#    '2nd-under-1-5': '1.55',
#    '2nd-over-0-5': '1.24',
#    '2nd-under-0-5': '3.40',
#    '2nd-over-2-5': '4.60',
#    '2nd-under-2-5': '1.14',
#    'away-total-goal-0': '1.66',
#    'away-total-goal-1': '2.34',
#    'away-total-goal-2': '6.53',
#    'home-total-goal-1': '1.80',
#    'home-total-goal-2': '2.21',
#    'home-total-goal-3+': '3.69',
#    'away-over-0-5': '1.98',
#    'away-under-0-5': '1.66',
#    'away-over-1-5': '6.25',
#    'away-under-1-5': '1.08',
#    'home-over-1-5': '1.65',
#    'home-under-1-5': '2.00',
#    'home-over-2-5': '4.10',
#    'home-under-2-5': '1.17',
#    'rest-of-match-1': '2.23',
#    'rest-of-match-0': '2.19',
#    'rest-of-match-2': '3.14',
#    'next-goal-2-1': '1.95',
#    'next-goal-2-0': '3.23',
#    'next-goal-2-2': '2.52',
#    'home-over-3-5': '12.00',
#    'home-under-3-5': '1.02'}},
#  '1411170377172529': {'mid': '1411170377172529',
#   'home': 'FK Trayal Krusevac',
#   'away': 'FK Zeleznicar Pancevo',
#   'country_leagues': 'Serbia - Prva Liga',
#   'leagues': 'Prva Liga',
#   'country': 'Serbia',
#   'score': '0-0',
#   'home_score': 0,
#   'away_score': 0,
#   'periodID': '2',
#   'periodTXT': 'HalfTime',
#   'periodTime': 1668445274,
#   'startTime': 1668445200,
#   'lastUpdateTime': 1668448849,
#   'minutes': 1,
#   'status': '1',
#   'importancy': 15,
#   'odds': {'home': '5.50',
#    'draw': '2.10',
#    'away': '1.98',
#    'both-team-score-yes': '4.18',
#    'both-team-score-no': '1.15',
#    'double-chance-1-0': '1.65',
#    'double-chance-0-2': '1.10',
#    'double-chance-1-2': '1.57',
#    'over-2-5': '6.00',
#    'under-2-5': '1.09',
#    'over-1-5': '2.50',
#    'under-1-5': '1.41',
#    '2nd-1': '5.50',
#    '2nd-0': '2.10',
#    '2nd-2': '1.98',
#    'total-goal-0': '2.43',
#    'total-goal-1': '2.30',
#    'total-goal-2': '3.38',
#    'total-goal-3': '6.98',
#    '1-hcap-1-+1': '1.65',
#    '1-hcap-0-+1': '2.66',
#    '1-hcap-2--1': '4.32',
#    '2nd-over-1-5': '2.50',
#    '2nd-under-1-5': '1.41',
#    '2nd-over-0-5': '1.36',
#    '2nd-under-0-5': '2.70',
#    'rest-of-match-1': '5.50',
#    'rest-of-match-0': '2.10',
#    'rest-of-match-2': '1.98',
#    'next-goal-1-1': '3.90',
#    'next-goal-1-0': '2.57',
#    'next-goal-1-2': '1.74',
#    'over-0-5': '1.36',
#    'under-0-5': '2.70'}},
#  '1411196255196256': {'mid': '1411196255196256',
#   'home': 'CD Mafra',
#   'away': 'Leixoes SC',
#   'country_leagues': 'Portugal - Liga Portugal 2',
#   'leagues': 'Liga Portugal 2',
#   'country': 'Portugal',
#   'score': '0-0',
#   'home_score': 0,
#   'away_score': 0,
#   'periodID': '1',
#   'periodTXT': '1st',
#   'periodTime': 1668448799,
#   'startTime': 1668448799,
#   'lastUpdateTime': 1668448849,
#   'minutes': 1,
#   'status': '1',
#   'importancy': 2,
#   'odds': {'home': '2.00',
#    'draw': '3.10',
#    'away': '2.95',
#    '1st-1': '2.60',
#    '1st-0': '2.05',
#    '1st-2': '3.50',
#    '2nd-1': '2.30',
#    '2nd-0': '2.40',
#    '2nd-2': '3.20',
#    'both-team-score-yes': '1.62',
#    'both-team-score-no': '1.95',
#    '1st-both-team-score-yes': '3.61',
#    '1st-both-team-score-no': '1.20',
#    'double-chance-1-0': '1.30',
#    'double-chance-0-2': '1.65',
#    'double-chance-1-2': '1.28',
#    'draw-refund-1': '1.50',
#    'draw-refund-2': '2.25',
#    'total-goal-0': '8.10',
#    'total-goal-1': '4.14',
#    'total-goal-2': '3.15',
#    'total-goal-3': '3.42',
#    'total-goal-4': '4.50',
#    'total-goal-5': '7.20',
#    'total-goal-6': '12.15',
#    'away-total-goal-0': '2.57',
#    'away-total-goal-1': '2.16',
#    'away-total-goal-2': '3.38',
#    'away-total-goal-3+': '5.40',
#    'home-total-goal-0': '3.42',
#    'home-total-goal-1': '2.39',
#    'home-total-goal-2': '2.97',
#    'home-total-goal-3+': '3.51',
#    '1st-total-goal-0': '2.52',
#    '1st-total-goal-1': '2.25',
#    '1st-total-goal-2': '3.33',
#    '1st-total-goal-3+': '5.40',
#    'total-goal-0-1': '3.06',
#    'total-goal-2-3': '1.78',
#    'total-goal-4+': '2.48',
#    'total-goal-0-2': '1.69',
#    'total-goal-3-4': '2.13',
#    'total-goal-5+': '4.50',
#    'total-goal-0-3': '1.35',
#    'total-goal-4-5': '3.06',
#    'total-goal-6+': '8.55',
#    'next-goal-1-1': '1.73',
#    'next-goal-1-0': '8.55',
#    'next-goal-1-2': '2.09',
#    '1-hcap-1--1': '3.24',
#    '1-hcap-0--1': '3.33',
#    '1-hcap-2-+1': '1.65',
#    '1-hcap-1-+1': '1.30',
#    '1-hcap-0-+1': '4.28',
#    '1-hcap-2--1': '5.63',
#    'over-2-5': '1.73',
#    'under-2-5': '1.88',
#    'over-1-5': '1.23',
#    'under-1-5': '3.40',
#    'over-3-5': '2.75',
#    'under-3-5': '1.35',
#    'over-0-5': '1.04',
#    'under-0-5': '9.00',
#    'over-4-5': '5.00',
#    'under-4-5': '1.12',
#    'over-5-5': '9.50',
#    'under-5-5': '1.04',
#    'away-over-1-5': '2.55',
#    'away-under-1-5': '1.40',
#    'away-over-0-5': '1.33',
#    'away-under-0-5': '2.85',
#    'away-over-2-5': '6.00',
#    'away-under-2-5': '1.09',
#    'home-over-1-5': '1.93',
#    'home-under-1-5': '1.68',
#    'home-over-0-5': '1.20',
#    'home-under-0-5': '3.80',
#    'home-over-2-5': '3.90',
#    'home-under-2-5': '1.19',
#    '1st-over-0-5': '1.33',
#    '1st-under-0-5': '2.80',
#    '1st-over-1-5': '2.50',
#    '1st-under-1-5': '1.42',
#    '1st-over-2-5': '6.00',
#    '1st-under-2-5': '1.09',
#    '1st-under-3-5': '1.01',
#    'away-1st-over-0-5': '2.15',
#    'away-1st-under-0-5': '1.55',
#    'away-1st-over-1-5': '7.25',
#    'away-1st-under-1-5': '1.06',
#    'home-1st-over-0-5': '1.82',
#    'home-1st-under-0-5': '1.78',
#    'home-1st-over-1-5': '5.00',
#    'home-1st-under-1-5': '1.12',
#    '2nd-over-1-5': '1.93',
#    '2nd-under-1-5': '1.70',
#    '2nd-over-0-5': '1.20',
#    '2nd-under-0-5': '3.80',
#    '2nd-over-2-5': '3.90',
#    '2nd-under-2-5': '1.19',
#    'away-1st-total-goal-0': '1.55',
#    'away-1st-total-goal-1': '2.43',
#    'away-1st-total-goal-2': '7.43',
#    'home-1st-total-goal-0': '1.60',
#    'home-1st-total-goal-1': '2.25',
#    'home-1st-total-goal-2': '5.63',
#    'rest-of-match-1': '2.00',
#    'rest-of-match-0': '3.10',
#    'rest-of-match-2': '2.95',
#    '1st-rest-of-match-1': '2.60',
#    '1st-rest-of-match-0': '2.05',
#    '1st-rest-of-match-2': '3.50'}},
#  '1411204887196012': {'mid': '1411204887196012',
#   'home': 'TSV 1860 Munich',
#   'away': 'Rot-Weiss Essen',
#   'country_leagues': 'Germany - 3rd Liga',
#   'leagues': '3rd Liga',
#   'country': 'Germany',
#   'score': '0-0',
#   'home_score': 0,
#   'away_score': 0,
#   'periodID': '',
#   'periodTXT': '',
#   'periodTime': 1668448852,
#   'startTime': 1668448800,
#   'lastUpdateTime': 1668448849,
#   'minutes': 0,
#   'status': '1',
#   'importancy': 1,
#   'odds': {'home': '1.83',
#    'draw': '3.40',
#    'away': '3.60',
#    'double-chance-1-0': '1.25',
#    'double-chance-0-2': '1.67',
#    'double-chance-1-2': '1.28',
#    'draw-refund-1': '1.39',
#    'draw-refund-2': '2.75',
#    'total-goal-0': '9.45',
#    'total-goal-1': '4.73',
#    'total-goal-2': '3.38',
#    'total-goal-3': '3.51',
#    'total-goal-4': '4.50',
#    'total-goal-5': '7.20',
#    'total-goal-6': '12.15',
#    'home-total-goal-0': '4.14',
#    'home-total-goal-1': '2.58',
#    'home-total-goal-2': '2.97',
#    'home-total-goal-3+': '3.06',
#    'away-total-goal-0': '2.52',
#    'away-total-goal-1': '2.21',
#    'away-total-goal-2': '3.69',
#    'away-total-goal-3+': '6.30',
#    'both-team-score-yes': '1.63',
#    'both-team-score-no': '2.00',
#    'total-goal-0-1': '3.42',
#    'total-goal-2-3': '1.85',
#    'total-goal-4+': '2.39',
#    'total-goal-0-2': '1.80',
#    'total-goal-3-4': '2.16',
#    'total-goal-5+': '4.32',
#    'total-goal-0-3': '1.41',
#    'total-goal-4-5': '3.06',
#    'total-goal-6+': '8.33',
#    '2nd-1': '2.15',
#    '2nd-0': '2.55',
#    '2nd-2': '3.70',
#    'over-2-5': '1.68',
#    'under-2-5': '2.00',
#    'over-1-5': '1.23',
#    'under-1-5': '3.80',
#    'over-3-5': '2.65',
#    'under-3-5': '1.41',
#    'over-0-5': '1.04',
#    'under-0-5': '10.50',
#    'over-4-5': '4.80',
#    'under-4-5': '1.16',
#    'over-5-5': '9.25',
#    'under-5-5': '1.05',
#    'under-6-5': '1.01',
#    '2nd-over-1-5': '1.88',
#    '2nd-under-1-5': '1.80',
#    '2nd-over-0-5': '1.19',
#    '2nd-under-0-5': '4.20',
#    '2nd-over-2-5': '3.70',
#    '2nd-under-2-5': '1.23',
#    'home-over-1-5': '1.80',
#    'home-under-1-5': '1.88',
#    'home-over-0-5': '1.17',
#    'home-under-0-5': '4.60',
#    'home-over-2-5': '3.40',
#    'home-under-2-5': '1.27',
#    'home-over-3-5': '7.50',
#    'home-under-3-5': '1.08',
#    'away-over-0-5': '1.38',
#    'away-under-0-5': '2.80',
#    'away-over-1-5': '2.80',
#    'away-under-1-5': '1.38',
#    'away-over-2-5': '7.00',
#    'away-under-2-5': '1.08',
#    'away-under-3-5': '1.01',
#    '1-hcap-1--1': '2.88',
#    '1-hcap-0--1': '3.33',
#    '1-hcap-2-+1': '1.67',
#    '1-hcap-1--2': '5.85',
#    '1-hcap-0--2': '4.95',
#    '1-hcap-2-+2': '1.30',
#    '1-hcap-1-+1': '1.25',
#    '1-hcap-0-+1': '4.95',
#    '1-hcap-2--1': '7.20',
#    'rest-of-match-1': '1.83',
#    'rest-of-match-0': '3.40',
#    'rest-of-match-2': '3.60'}},
#  '1411231072231316': {'mid': '1411231072231316',
#   'home': 'Sakaryaspor',
#   'away': 'Caykur Rizespor',
#   'country_leagues': 'Turkey - 1. Lig',
#   'leagues': '1. Lig',
#   'country': 'Turkey',
#   'score': '1-0',
#   'home_score': 1,
#   'away_score': 0,
#   'periodID': '2',
#   'periodTXT': 'HalfTime',
#   'periodTime': 1668445275,
#   'startTime': 1668445200,
#   'lastUpdateTime': 1668448849,
#   'minutes': 1,
#   'status': '1',
#   'importancy': 5,
#   'odds': {'home': '1.49',
#    'draw': '3.25',
#    'away': '6.00',
#    '2nd-1': '3.10',
#    '2nd-0': '2.50',
#    '2nd-2': '2.30',
#    'both-team-score-yes': '1.55',
#    'both-team-score-no': '2.04',
#    'double-chance-1-0': '1.09',
#    'double-chance-0-2': '2.07',
#    'double-chance-1-2': '1.26',
#    'draw-refund-1': '1.14',
#    'draw-refund-2': '4.60',
#    'total-goal-1': '3.60',
#    'total-goal-2': '2.34',
#    'total-goal-3': '2.93',
#    'total-goal-4': '4.95',
#    'total-goal-5': '10.35',
#    'away-total-goal-0': '1.94',
#    'away-total-goal-1': '2.12',
#    'away-total-goal-2': '4.32',
#    'away-total-goal-3+': '9.90',
#    'home-total-goal-1': '1.64',
#    'home-total-goal-2': '2.25',
#    'home-total-goal-3+': '4.32',
#    'total-goal-0-1': '3.60',
#    'total-goal-2-3': '1.57',
#    'total-goal-4+': '3.42',
#    'total-goal-0-2': '1.70',
#    'total-goal-3-4': '2.03',
#    'total-goal-5+': '7.88',
#    'total-goal-0-3': '1.20',
#    'total-goal-4-5': '3.78',
#    '1-hcap-1--1': '2.79',
#    '1-hcap-0--1': '2.25',
#    '1-hcap-2-+1': '2.07',
#    '1-hcap-1--2': '7.43',
#    '1-hcap-0--2': '3.78',
#    '1-hcap-2-+2': '1.28',
#    'over-2-5': '1.90',
#    'under-2-5': '1.70',
#    'over-1-5': '1.18',
#    'under-1-5': '4.00',
#    'over-3-5': '3.80',
#    'under-3-5': '1.20',
#    'over-4-5': '8.75',
#    'under-4-5': '1.04',
#    'away-over-1-5': '3.75',
#    'away-under-1-5': '1.20',
#    'away-over-0-5': '1.55',
#    'away-under-0-5': '2.15',
#    'away-over-2-5': '11.00',
#    'away-under-2-5': '1.02',
#    'home-over-1-5': '1.78',
#    'home-under-1-5': '1.82',
#    'home-over-2-5': '4.80',
#    'home-under-2-5': '1.13',
#    'home-under-3-5': '1.01',
#    '2nd-over-1-5': '1.90',
#    '2nd-under-1-5': '1.70',
#    '2nd-over-0-5': '1.18',
#    '2nd-under-0-5': '4.00',
#    '2nd-over-2-5': '3.80',
#    '2nd-under-2-5': '1.20',
#    'rest-of-match-1': '2.95',
#    'rest-of-match-0': '2.38',
#    'rest-of-match-2': '2.19',
#    'next-goal-2-1': '2.33',
#    'next-goal-2-0': '3.80',
#    'next-goal-2-2': '1.90'}},
#  '1411231426138914': {'mid': '1411231426138914',
#   'home': 'Goztepe Izmir',
#   'away': 'Ankara Keciorengucu',
#   'country_leagues': 'Turkey - 1. Lig',
#   'leagues': '1. Lig',
#   'country': 'Turkey',
#   'score': '1-1',
#   'home_score': 1,
#   'away_score': 1,
#   'periodID': '2',
#   'periodTXT': 'HalfTime',
#   'periodTime': 1668445418,
#   'startTime': 1668445200,
#   'lastUpdateTime': 1668448849,
#   'minutes': 1,
#   'status': '1',
#   'importancy': 4,
#   'odds': {'home': '2.45',
#    'draw': '2.25',
#    'away': '3.25',
#    '2nd-1': '2.45',
#    '2nd-0': '2.25',
#    '2nd-2': '3.25',
#    'double-chance-1-0': '1.26',
#    'double-chance-0-2': '1.43',
#    'double-chance-1-2': '1.50',
#    'draw-refund-1': '1.58',
#    'draw-refund-2': '2.10',
#    'total-goal-2': '2.97',
#    'total-goal-3': '2.34',
#    'total-goal-4': '3.06',
#    'total-goal-5': '5.63',
#    'total-goal-6': '12.15',
#    'away-total-goal-1': '1.70',
#    'away-total-goal-2': '2.34',
#    'away-total-goal-3+': '5.18',
#    'home-total-goal-1': '1.76',
#    'home-total-goal-2': '2.21',
#    'home-total-goal-3+': '3.78',
#    'total-goal-2-3': '1.57',
#    'total-goal-4+': '1.89',
#    'total-goal-0-2': '2.97',
#    'total-goal-3-4': '1.58',
#    'total-goal-5+': '4.05',
#    'total-goal-0-3': '1.57',
#    'total-goal-4-5': '2.16',
#    'total-goal-6+': '9.45',
#    '1-hcap-1--1': '5.63',
#    '1-hcap-0--1': '3.15',
#    '1-hcap-2-+1': '1.43',
#    '1-hcap-1-+1': '1.26',
#    '1-hcap-0-+1': '3.78',
#    '1-hcap-2--1': '8.33',
#    'over-2-5': '1.25',
#    'under-2-5': '3.30',
#    'over-3-5': '2.10',
#    'under-3-5': '1.57',
#    'over-4-5': '4.50',
#    'under-4-5': '1.14',
#    'over-5-5': '10.50',
#    'under-5-5': '1.03',
#    'away-over-1-5': '1.90',
#    'away-under-1-5': '1.70',
#    'home-over-2-5': '4.20',
#    'home-under-2-5': '1.16',
#    'away-over-2-5': '5.75',
#    'away-under-2-5': '1.10',
#    'home-over-1-5': '1.66',
#    'home-under-1-5': '1.95',
#    'home-over-3-5': '12.50',
#    'home-under-3-5': '1.02',
#    '2nd-over-1-5': '2.10',
#    '2nd-under-1-5': '1.57',
#    '2nd-over-0-5': '1.25',
#    '2nd-under-0-5': '3.30',
#    '2nd-over-2-5': '4.50',
#    '2nd-under-2-5': '1.14',
#    'rest-of-match-1': '2.45',
#    'rest-of-match-0': '2.25',
#    'rest-of-match-2': '3.25',
#    'next-goal-3-1': '2.00',
#    'next-goal-3-0': '3.14',
#    'next-goal-3-2': '2.47'}},
#  '1411233906196031': {'mid': '1411233906196031',
#   'home': 'OFI Crete',
#   'away': 'APO Levadiakos',
#   'country_leagues': 'Greece - Super League',
#   'leagues': 'Super League',
#   'country': 'Greece',
#   'score': '0-1',
#   'home_score': 0,
#   'away_score': 1,
#   'periodID': '1',
#   'periodTXT': '1st',
#   'periodTime': 1668447102,
#   'startTime': 1668447103,
#   'lastUpdateTime': 1668448849,
#   'minutes': 1,
#   'status': '1',
#   'importancy': 1,
#   'odds': {'1st-1': '14.00',
#    '1st-0': '3.50',
#    '1st-2': '1.29',
#    'home': '2.90',
#    'draw': '2.85',
#    'away': '2.15',
#    'double-chance-1-0': '1.53',
#    'double-chance-0-2': '1.32',
#    'double-chance-1-2': '1.33',
#    'draw-refund-1': '2.10',
#    'draw-refund-2': '1.57',
#    'total-goal-1': '4.73',
#    'total-goal-2': '2.61',
#    'total-goal-3': '2.79',
#    'total-goal-4': '4.14',
#    'total-goal-5': '7.65',
#    'home-total-goal-0': '3.06',
#    'home-total-goal-1': '2.21',
#    'home-total-goal-2': '3.06',
#    'home-total-goal-3+': '4.32',
#    'away-total-goal-1': '1.53',
#    'away-total-goal-2': '2.52',
#    'away-total-goal-3+': '6.53',
#    '1st-total-goal-1': '1.50',
#    '1st-total-goal-2': '2.48',
#    '1st-total-goal-3+': '7.65',
#    'home-1st-total-goal-0': '1.33',
#    'home-1st-total-goal-1': '2.93',
#    'home-1st-total-goal-2': '12.60',
#    'away-1st-total-goal-1': '1.08',
#    'away-1st-total-goal-2': '5.85',
#    'both-team-score-yes': '1.24',
#    'both-team-score-no': '3.23',
#    '1st-both-team-score-yes': '2.66',
#    '1st-both-team-score-no': '1.33',
#    'total-goal-0-1': '4.73',
#    'total-goal-2-3': '1.63',
#    'total-goal-4+': '2.58',
#    'total-goal-0-2': '1.85',
#    'total-goal-3-4': '1.80',
#    'total-goal-5+': '5.40',
#    'total-goal-0-3': '1.32',
#    'total-goal-4-5': '2.97',
#    'total-goal-6+': '11.70',
#    '2nd-1': '1.75',
#    '2nd-0': '2.50',
#    '2nd-2': '5.50',
#    'over-2-5': '1.62',
#    'under-2-5': '2.05',
#    'over-1-5': '1.11',
#    'under-1-5': '5.25',
#    'over-3-5': '2.87',
#    'under-3-5': '1.32',
#    'over-4-5': '6.00',
#    'under-4-5': '1.09',
#    'over-5-5': '13.00',
#    'under-5-5': '1.01',
#    '1st-over-1-5': '2.25',
#    '1st-under-1-5': '1.50',
#    '1st-over-2-5': '8.50',
#    '1st-under-2-5': '1.04',
#    '2nd-over-1-5': '2.15',
#    '2nd-under-1-5': '1.57',
#    '2nd-over-0-5': '1.23',
#    '2nd-under-0-5': '3.50',
#    '2nd-over-2-5': '4.60',
#    '2nd-under-2-5': '1.14',
#    'home-over-1-5': '2.20',
#    'home-under-1-5': '1.53',
#    'home-over-0-5': '1.24',
#    'home-under-0-5': '3.40',
#    'home-over-2-5': '4.80',
#    'home-under-2-5': '1.13',
#    'away-over-1-5': '2.20',
#    'away-under-1-5': '1.53',
#    'away-over-2-5': '7.25',
#    'away-under-2-5': '1.06',
#    '1-hcap-1--1': '5.85',
#    '1-hcap-0--1': '3.90',
#    '1-hcap-2-+1': '1.32',
#    '1-hcap-1-+1': '1.53',
#    '1-hcap-0-+1': '2.79',
#    '1-hcap-2--1': '4.95',
#    'home-1st-over-0-5': '2.80',
#    'home-1st-under-0-5': '1.33',
#    'home-1st-over-1-5': '13.00',
#    'home-1st-under-1-5': '1.01',
#    'away-1st-over-1-5': '6.25',
#    'away-1st-under-1-5': '1.08',
#    'rest-of-match-1': '1.53',
#    'rest-of-match-0': '2.95',
#    'rest-of-match-2': '5.23',
#    '1st-rest-of-match-1': '2.95',
#    '1st-rest-of-match-0': '1.44',
#    '1st-rest-of-match-2': '7.60',
#    'next-goal-2-1': '1.47',
#    'next-goal-2-0': '4.99',
#    'next-goal-2-2': '3.42'}},
#  '1411234101234110': {'mid': '1411234101234110',
#   'home': 'CD Tondela',
#   'away': 'Moreirense',
#   'country_leagues': 'Portugal - Liga Portugal 2',
#   'leagues': 'Liga Portugal 2',
#   'country': 'Portugal',
#   'score': '0-0',
#   'home_score': 0,
#   'away_score': 0,
#   'periodID': '1',
#   'periodTXT': '1st',
#   'periodTime': 1668448810,
#   'startTime': 1668448800,
#   'lastUpdateTime': 1668448849,
#   'minutes': 1,
#   'status': '1',
#   'importancy': 3,
#   'odds': {'home': '2.90',
#    'draw': '2.95',
#    'away': '2.10',
#    '1st-1': '3.50',
#    '1st-0': '1.98',
#    '1st-2': '2.75',
#    '2nd-1': '3.20',
#    '2nd-0': '2.30',
#    '2nd-2': '2.45',
#    'both-team-score-yes': '1.75',
#    'both-team-score-no': '1.76',
#    '1st-both-team-score-yes': '4.11',
#    '1st-both-team-score-no': '1.16',
#    'double-chance-1-0': '1.58',
#    'double-chance-0-2': '1.31',
#    'double-chance-1-2': '1.30',
#    'draw-refund-1': '2.15',
#    'draw-refund-2': '1.55',
#    'total-goal-0': '6.75',
#    'total-goal-1': '3.69',
#    'total-goal-2': '2.97',
#    'total-goal-3': '3.51',
#    'total-goal-4': '4.95',
#    'total-goal-5': '8.33',
#    'away-total-goal-0': '2.97',
#    'away-total-goal-1': '2.25',
#    'away-total-goal-2': '3.15',
#    'away-total-goal-3+': '4.14',
#    'home-total-goal-0': '2.39',
#    'home-total-goal-1': '2.16',
#    'home-total-goal-2': '3.60',
#    'home-total-goal-3+': '6.08',
#    '1st-total-goal-0': '2.30',
#    '1st-total-goal-1': '2.21',
#    '1st-total-goal-2': '3.51',
#    '1st-total-goal-3+': '6.30',
#    'total-goal-0-1': '2.66',
#    'total-goal-2-3': '1.76',
#    'total-goal-4+': '2.93',
#    'total-goal-0-2': '1.68',
#    'total-goal-3-4': '2.25',
#    'total-goal-5+': '5.63',
#    'total-goal-0-3': '1.26',
#    'total-goal-4-5': '3.51',
#    'total-goal-6+': '11.25',
#    'next-goal-1-1': '2.09',
#    'next-goal-1-0': '7.13',
#    'next-goal-1-2': '1.69',
#    '1-hcap-1-+1': '1.58',
#    '1-hcap-0-+1': '3.33',
#    '1-hcap-2--1': '3.60',
#    '1-hcap-1--1': '5.63',
#    '1-hcap-0--1': '4.05',
#    '1-hcap-2-+1': '1.31',
#    'over-2-5': '1.93',
#    'under-2-5': '1.68',
#    'over-1-5': '1.31',
#    'under-1-5': '2.95',
#    'over-3-5': '3.25',
#    'under-3-5': '1.26',
#    'over-0-5': '1.06',
#    'under-0-5': '7.50',
#    'over-4-5': '6.25',
#    'under-4-5': '1.08',
#    'over-5-5': '12.50',
#    'under-5-5': '1.02',
#    'away-over-1-5': '2.15',
#    'away-under-1-5': '1.55',
#    'away-over-0-5': '1.25',
#    'away-under-0-5': '3.30',
#    'away-over-2-5': '4.60',
#    'away-under-2-5': '1.14',
#    'home-over-1-5': '2.75',
#    'home-under-1-5': '1.34',
#    'home-over-0-5': '1.38',
#    'home-under-0-5': '2.65',
#    'home-over-2-5': '6.75',
#    'home-under-2-5': '1.07',
#    '1st-over-0-5': '1.40',
#    '1st-under-0-5': '2.55',
#    '1st-over-1-5': '2.80',
#    '1st-under-1-5': '1.34',
#    '1st-over-2-5': '7.00',
#    '1st-under-2-5': '1.06',
#    'away-1st-over-0-5': '1.95',
#    'away-1st-under-0-5': '1.68',
#    'away-1st-over-1-5': '6.00',
#    'away-1st-under-1-5': '1.09',
#    'home-1st-over-0-5': '2.25',
#    'home-1st-under-0-5': '1.50',
#    'home-1st-over-1-5': '8.00',
#    'home-1st-under-1-5': '1.05',
#    '2nd-over-1-5': '2.10',
#    '2nd-under-1-5': '1.57',
#    '2nd-over-0-5': '1.24',
#    '2nd-under-0-5': '3.40',
#    '2nd-over-2-5': '4.50',
#    '2nd-under-2-5': '1.15',
#    'away-1st-total-goal-0': '1.68',
#    'away-1st-total-goal-1': '2.34',
#    'away-1st-total-goal-2': '6.30',
#    'home-1st-total-goal-0': '1.50',
#    'home-1st-total-goal-1': '2.52',
#    'home-1st-total-goal-2': '8.10',
#    'rest-of-match-1': '2.90',
#    'rest-of-match-0': '2.95',
#    'rest-of-match-2': '2.10',
#    '1st-rest-of-match-1': '3.50',
#    '1st-rest-of-match-0': '1.98',
#    '1st-rest-of-match-2': '2.75'}},
#  '1411234241234233': {'mid': '1411234241234233',
#   'home': 'SonderjyskE',
#   'away': 'Vejle BK',
#   'country_leagues': 'Denmark - 1st Division',
#   'leagues': '1st Division',
#   'country': 'Denmark',
#   'score': '0-0',
#   'home_score': 0,
#   'away_score': 0,
#   'periodID': '',
#   'periodTXT': '',
#   'periodTime': 1668448852,
#   'startTime': 1668448800,
#   'lastUpdateTime': 1668448849,
#   'minutes': 0,
#   'status': '1',
#   'importancy': 9,
#   'odds': {'home': '2.10',
#    'draw': '3.10',
#    'away': '3.00',
#    '2nd-1': '2.50',
#    '2nd-0': '2.40',
#    '2nd-2': '3.30',
#    'both-team-score-yes': '1.69',
#    'both-team-score-no': '1.81',
#    'double-chance-1-0': '1.34',
#    'double-chance-0-2': '1.63',
#    'draw-refund-1': '1.57',
#    'draw-refund-2': '2.20',
#    'total-goal-0': '7.65',
#    'total-goal-1': '3.90',
#    'total-goal-2': '3.15',
#    'total-goal-3': '3.60',
#    'total-goal-4': '5.18',
#    'total-goal-5': '9.00',
#    'away-total-goal-0': '2.48',
#    'away-total-goal-1': '2.21',
#    'away-total-goal-2': '3.69',
#    'away-total-goal-3+': '6.30',
#    'home-total-goal-0': '3.15',
#    'home-total-goal-1': '2.34',
#    'home-total-goal-2': '3.24',
#    'home-total-goal-3+': '4.28',
#    'total-goal-0-1': '2.79',
#    'total-goal-2-3': '1.80',
#    'total-goal-4+': '2.97',
#    'total-goal-0-2': '1.75',
#    'total-goal-3-4': '2.30',
#    'total-goal-5+': '5.85',
#    'total-goal-0-3': '1.28',
#    'total-goal-4-5': '3.60',
#    'total-goal-6+': '11.70',
#    'next-goal-1-1': '1.73',
#    'next-goal-1-0': '8.08',
#    'next-goal-1-2': '2.14',
#    '1-hcap-1-+1': '1.34',
#    '1-hcap-0-+1': '4.28',
#    '1-hcap-2--1': '5.85',
#    '1-hcap-1--1': '3.69',
#    '1-hcap-0--1': '3.42',
#    '1-hcap-2-+1': '1.63',
#    'over-2-5': '1.95',
#    'under-2-5': '1.75',
#    'over-3-5': '3.30',
#    'under-3-5': '1.28',
#    'over-1-5': '1.32',
#    'under-1-5': '3.10',
#    'over-4-5': '6.50',
#    'under-4-5': '1.10',
#    'over-0-5': '1.06',
#    'under-0-5': '8.50',
#    'over-5-5': '13.00',
#    'under-5-5': '1.03',
#    'away-under-1-5': '1.37',
#    'away-over-0-5': '1.39',
#    'away-under-0-5': '2.75',
#    'away-over-2-5': '7.00',
#    'away-under-2-5': '1.08',
#    'away-under-3-5': '1.01',
#    'home-over-1-5': '2.20',
#    'home-under-1-5': '1.58',
#    'home-over-0-5': '1.26',
#    'home-under-0-5': '3.50',
#    'home-over-2-5': '4.75',
#    'home-under-2-5': '1.16',
#    'home-over-3-5': '11.50',
#    'home-under-3-5': '1.03',
#    '2nd-over-1-5': '2.10',
#    '2nd-under-1-5': '1.63',
#    '2nd-over-2-5': '4.60',
#    '2nd-under-2-5': '1.17',
#    '2nd-over-0-5': '1.25',
#    '2nd-under-0-5': '3.60',
#    '1-hcap-1--2': '8.33',
#    '1-hcap-0--2': '5.63',
#    '1-hcap-2-+2': '1.20',
#    'rest-of-match-1': '2.10',
#    'rest-of-match-0': '3.10',
#    'rest-of-match-2': '3.00'}},
#  '1411262285262290': {'mid': '1411262285262290',
#   'home': 'Republic of Ireland (Women) (W)',
#   'away': 'Morocco (Women) (W)',
#   'country_leagues': 'World - International Friendlies - Women',
#   'leagues': 'International Friendlies - Women',
#   'country': 'World',
#   'score': '2-0',
#   'home_score': 2,
#   'away_score': 0,
#   'periodID': '3',
#   'periodTXT': '2nd',
#   'periodTime': 1668448841,
#   'startTime': 1668445200,
#   'lastUpdateTime': 1668448849,
#   'minutes': 46,
#   'status': '1',
#   'importancy': 6,
#   'odds': {'both-team-score-yes': '2.33',
#    'both-team-score-no': '1.42',
#    'over-2-5': '1.18',
#    'under-2-5': '4.00',
#    'over-3-5': '1.88',
#    'under-3-5': '1.73',
#    '2nd-1': '1.66',
#    '2nd-0': '2.75',
#    '2nd-2': '5.50',
#    'total-goal-2': '3.60',
#    'total-goal-3': '2.39',
#    'total-goal-4': '2.93',
#    'total-goal-5': '4.95',
#    'total-goal-6': '9.90',
#    '2nd-over-1-5': '1.88',
#    '2nd-under-1-5': '1.73',
#    '1-hcap-1--3': '2.97',
#    '1-hcap-0--3': '2.58',
#    '1-hcap-2-+3': '1.78',
#    'over-4-5': '3.75',
#    'under-4-5': '1.20',
#    'rest-of-match-1': '1.66',
#    'rest-of-match-0': '2.61',
#    'rest-of-match-2': '5.23',
#    'next-goal-3-1': '1.57',
#    'next-goal-3-0': '3.80',
#    'next-goal-3-2': '3.56',
#    '2nd-over-0-5': '1.18',
#    '2nd-under-0-5': '4.00'}},
#  '1411262477262726': {'mid': '1411262477262726',
#   'home': 'Scotland (Women) (W)',
#   'away': 'Venezuela (Women) (W)',
#   'country_leagues': 'World - International Friendlies - Women',
#   'leagues': 'International Friendlies - Women',
#   'country': 'World',
#   'score': '0-0',
#   'home_score': 0,
#   'away_score': 0,
#   'periodID': '1',
#   'periodTXT': '1st',
#   'periodTime': 1668448732,
#   'startTime': 1668448731,
#   'lastUpdateTime': 1668448849,
#   'minutes': 1,
#   'status': '1',
#   'importancy': 7,
#   'odds': {'home': '1.30',
#    'draw': '4.60',
#    'away': '6.50',
#    'both-team-score-yes': '1.81',
#    'both-team-score-no': '1.71',
#    'double-chance-1-0': '1.07',
#    'double-chance-0-2': '2.70',
#    'double-chance-1-2': '1.14',
#    'over-2-5': '1.57',
#    'under-2-5': '2.10',
#    'over-3-5': '2.45',
#    'under-3-5': '1.43',
#    'over-1-5': '1.18',
#    'under-1-5': '4.00',
#    '1st-1': '1.75',
#    '1st-0': '2.45',
#    '1st-2': '6.00',
#    '2nd-1': '1.58',
#    '2nd-0': '2.87',
#    '2nd-2': '6.00',
#    '1st-both-team-score-yes': '4.18',
#    '1st-both-team-score-no': '1.15',
#    'total-goal-0': '10.80',
#    'total-goal-1': '4.50',
#    'total-goal-2': '3.38',
#    'total-goal-3': '3.33',
#    'total-goal-4': '4.28',
#    'total-goal-5': '6.30',
#    'total-goal-6': '10.35',
#    '1st-total-goal-0': '2.88',
#    '1st-total-goal-1': '2.21',
#    '1st-total-goal-2': '3.15',
#    '1st-total-goal-3+': '4.73',
#    '1-hcap-1--1': '1.69',
#    '1-hcap-0--1': '3.06',
#    '1-hcap-2-+1': '2.70',
#    '1st-over-1-5': '2.25',
#    '1st-under-1-5': '1.50',
#    '1st-over-0-5': '1.26',
#    '1st-under-0-5': '3.20',
#    '2nd-over-1-5': '1.80',
#    '2nd-under-1-5': '1.80',
#    '2nd-over-2-5': '3.40',
#    '2nd-under-2-5': '1.23',
#    'rest-of-match-1': '1.30',
#    'rest-of-match-0': '4.60',
#    'rest-of-match-2': '6.50',
#    '1st-rest-of-match-1': '1.75',
#    '1st-rest-of-match-0': '2.45',
#    '1st-rest-of-match-2': '6.00',
#    'next-goal-1-1': '1.31',
#    'next-goal-1-0': '11.40',
#    'next-goal-1-2': '3.33'}},
#  '1411318703316457': {'mid': '1411318703316457',
#   'home': 'Al Sahel (U21) (KUW)',
#   'away': 'Al Salmiya (U21)',
#   'country_leagues': 'Kuwait - Kuwait Youth League',
#   'leagues': 'Kuwait Youth League',
#   'country': 'Kuwait',
#   'score': '2-3',
#   'home_score': 2,
#   'away_score': 3,
#   'periodID': '3',
#   'periodTXT': '2nd',
#   'periodTime': 1668447187,
#   'startTime': 1668443400,
#   'lastUpdateTime': 1668448849,
#   'minutes': 73,
#   'status': '1',
#   'importancy': 10,
#   'odds': {'home': '12.00',
#    'draw': '4.00',
#    'away': '1.25',
#    'double-chance-1-0': '2.97',
#    'double-chance-0-2': '1.02',
#    'double-chance-1-2': '1.18',
#    '2nd-0': '4.10',
#    '2nd-2': '13.00',
#    'total-goal-5': '1.85',
#    'total-goal-6': '2.13',
#    '2nd-over-1-5': '1.61',
#    '2nd-under-1-5': '2.05',
#    '2nd-over-2-5': '4.10',
#    '2nd-under-2-5': '1.18',
#    'over-5-5': '1.61',
#    'under-5-5': '2.05',
#    'over-6-5': '4.10',
#    'under-6-5': '1.18',
#    'over-7-5': '12.00',
#    'under-7-5': '1.02',
#    'rest-of-match-2': '3.33',
#    'rest-of-match-0': '1.68'}},
#  '1411318705318706': {'mid': '1411318705318706',
#   'home': 'Khaitan (U21)',
#   'away': 'Qadsia SC (U21)',
#   'country_leagues': 'Kuwait - Kuwait Youth League',
#   'leagues': 'Kuwait Youth League',
#   'country': 'Kuwait',
#   'score': '0-0',
#   'home_score': 0,
#   'away_score': 0,
#   'periodID': '3',
#   'periodTXT': '2nd',
#   'periodTime': 1668447332,
#   'startTime': 1668443400,
#   'lastUpdateTime': 1668448849,
#   'minutes': 71,
#   'status': '1',
#   'importancy': 11,
#   'odds': {'home': '4.40',
#    'draw': '1.82',
#    'away': '2.65',
#    'double-chance-1-0': '1.37',
#    'double-chance-0-2': '1.15',
#    'double-chance-1-2': '1.60',
#    'over-2-5': '11.50',
#    'under-2-5': '1.02',
#    '2nd-1': '4.40',
#    '2nd-0': '1.82',
#    '2nd-2': '2.65',
#    'both-team-score-yes': '6.18',
#    'both-team-score-no': '1.07',
#    'total-goal-0': '1.89',
#    'total-goal-1': '2.12',
#    'total-goal-2': '4.50',
#    'total-goal-3': '11.70',
#    '1-hcap-1-+1': '1.37',
#    '1-hcap-0-+1': '2.97',
#    '1-hcap-2--1': '8.10',
#    '2nd-over-1-5': '3.90',
#    '2nd-under-1-5': '1.19',
#    'rest-of-match-1': '4.40',
#    'rest-of-match-0': '1.82',
#    'rest-of-match-2': '2.65',
#    'next-goal-1-1': '3.56',
#    'next-goal-1-0': '2.00',
#    'next-goal-1-2': '2.28',
#    'over-1-5': '3.90',
#    'under-1-5': '1.19',
#    'over-0-5': '1.58',
#    'under-0-5': '2.10',
#    '2nd-over-0-5': '1.58',
#    '2nd-under-0-5': '2.10'}}}

# %%
df.keys()
# Out:
# dict_keys(['1411131116131109', '1411138799131115', '1411160050131118', '1411170377172529', '1411196255196256', '1411204887196012', '1411231072231316', '1411231426138914', '1411233906196031', '1411234101234110', '1411234241234233', '1411262285262290', '1411262477262726', '1411318703316457', '1411318705318706'])

# %%
df['1411231426138914']
# Out:
# {'mid': '1411231426138914',
#  'home': 'Goztepe Izmir',
#  'away': 'Ankara Keciorengucu',
#  'country_leagues': 'Turkey - 1. Lig',
#  'leagues': '1. Lig',
#  'country': 'Turkey',
#  'score': '1-1',
#  'home_score': 1,
#  'away_score': 1,
#  'periodID': '2',
#  'periodTXT': 'HalfTime',
#  'periodTime': 1668445418,
#  'startTime': 1668445200,
#  'lastUpdateTime': 1668448849,
#  'minutes': 1,
#  'status': '1',
#  'importancy': 4,
#  'odds': {'home': '2.45',
#   'draw': '2.25',
#   'away': '3.25',
#   '2nd-1': '2.45',
#   '2nd-0': '2.25',
#   '2nd-2': '3.25',
#   'double-chance-1-0': '1.26',
#   'double-chance-0-2': '1.43',
#   'double-chance-1-2': '1.50',
#   'draw-refund-1': '1.58',
#   'draw-refund-2': '2.10',
#   'total-goal-2': '2.97',
#   'total-goal-3': '2.34',
#   'total-goal-4': '3.06',
#   'total-goal-5': '5.63',
#   'total-goal-6': '12.15',
#   'away-total-goal-1': '1.70',
#   'away-total-goal-2': '2.34',
#   'away-total-goal-3+': '5.18',
#   'home-total-goal-1': '1.76',
#   'home-total-goal-2': '2.21',
#   'home-total-goal-3+': '3.78',
#   'total-goal-2-3': '1.57',
#   'total-goal-4+': '1.89',
#   'total-goal-0-2': '2.97',
#   'total-goal-3-4': '1.58',
#   'total-goal-5+': '4.05',
#   'total-goal-0-3': '1.57',
#   'total-goal-4-5': '2.16',
#   'total-goal-6+': '9.45',
#   '1-hcap-1--1': '5.63',
#   '1-hcap-0--1': '3.15',
#   '1-hcap-2-+1': '1.43',
#   '1-hcap-1-+1': '1.26',
#   '1-hcap-0-+1': '3.78',
#   '1-hcap-2--1': '8.33',
#   'over-2-5': '1.25',
#   'under-2-5': '3.30',
#   'over-3-5': '2.10',
#   'under-3-5': '1.57',
#   'over-4-5': '4.50',
#   'under-4-5': '1.14',
#   'over-5-5': '10.50',
#   'under-5-5': '1.03',
#   'away-over-1-5': '1.90',
#   'away-under-1-5': '1.70',
#   'home-over-2-5': '4.20',
#   'home-under-2-5': '1.16',
#   'away-over-2-5': '5.75',
#   'away-under-2-5': '1.10',
#   'home-over-1-5': '1.66',
#   'home-under-1-5': '1.95',
#   'home-over-3-5': '12.50',
#   'home-under-3-5': '1.02',
#   '2nd-over-1-5': '2.10',
#   '2nd-under-1-5': '1.57',
#   '2nd-over-0-5': '1.25',
#   '2nd-under-0-5': '3.30',
#   '2nd-over-2-5': '4.50',
#   '2nd-under-2-5': '1.14',
#   'rest-of-match-1': '2.45',
#   'rest-of-match-0': '2.25',
#   'rest-of-match-2': '3.25',
#   'next-goal-3-1': '2.00',
#   'next-goal-3-0': '3.14',
#   'next-goal-3-2': '2.47'}}

# %%
#minigame - betting
