# %%
import requests

url = "https://api-football-beta.p.rapidapi.com/odds/bets"

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "api-football-beta.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print (type(response.json()))
print(response.json())
df = response.json()
# Out:
# <class 'dict'>
# ...

# %%
import requests

url = "https://api-football-beta.p.rapidapi.com/teams/statistics"

querystring = {"team":"33","season":"2019","league":"39"}

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "api-football-beta.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print (type(response.json()))
print(response.json())
df = response.json()
# Out:
# <class 'dict'>
# ...

# %%
df['response']['team']['name']
# Out:
# 'Manchester United'

# %%
import requests

url = "https://api-football-beta.p.rapidapi.com/standings"

querystring = {"season":"2019","league":"39"}

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "api-football-beta.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print (type(response.json()))
print(response.json())
df = response.json()
# Out:
# <class 'dict'>
# ...

# %%
df['response'][0]['league'].keys()
# Out:
# dict_keys(['id', 'name', 'country', 'logo', 'flag', 'season', 'standings'])

# %%
df['response'][0]['league']
# Out:
# {'id': 39,
#  'name': 'Premier League',
#  'country': 'England',
#  'logo': 'https://media.api-sports.io/football/leagues/39.png',
#  'flag': 'https://media.api-sports.io/flags/gb.svg',
#  'season': 2019,
#  'standings': [[{'rank': 1,
#     'team': {'id': 40,
#      'name': 'Liverpool',
#      'logo': 'https://media.api-sports.io/football/teams/40.png'},
#     'points': 99,
#     'goalsDiff': 52,
#     'group': 'Premier League',
#     'form': 'WWLDW',
#     'status': 'same',
#     'description': 'Promotion - Champions League (Group Stage)',
#     'all': {'played': 38,
#      'win': 32,
#      'draw': 3,
#      'lose': 3,
#      'goals': {'for': 85, 'against': 33}},
#     'home': {'played': 19,
#      'win': 18,
#      'draw': 1,
#      'lose': 0,
#      'goals': {'for': 52, 'against': 16}},
#     'away': {'played': 19,
#      'win': 14,
#      'draw': 2,
#      'lose': 3,
#      'goals': {'for': 33, 'against': 17}},
#     'update': '2020-07-26T00:00:00+00:00'},
#    {'rank': 2,
# ...

# %%
df['response'][0]['league']['standings'][0]
# Out:
# [{'rank': 1,
#   'team': {'id': 40,
#    'name': 'Liverpool',
#    'logo': 'https://media.api-sports.io/football/teams/40.png'},
#   'points': 99,
#   'goalsDiff': 52,
#   'group': 'Premier League',
#   'form': 'WWLDW',
#   'status': 'same',
#   'description': 'Promotion - Champions League (Group Stage)',
#   'all': {'played': 38,
#    'win': 32,
#    'draw': 3,
#    'lose': 3,
#    'goals': {'for': 85, 'against': 33}},
#   'home': {'played': 19,
#    'win': 18,
#    'draw': 1,
#    'lose': 0,
#    'goals': {'for': 52, 'against': 16}},
#   'away': {'played': 19,
#    'win': 14,
#    'draw': 2,
#    'lose': 3,
#    'goals': {'for': 33, 'against': 17}},
#   'update': '2020-07-26T00:00:00+00:00'},
#  {'rank': 2,
#   'team': {'id': 50,
#    'name': 'Manchester City',
#    'logo': 'https://media.api-sports.io/football/teams/50.png'},
#   'points': 81,
#   'goalsDiff': 67,
#   'group': 'Premier League',
#   'form': 'WWWWW',
#   'status': 'same',
# ...

# %%
df['response'][0]['league'].keys()
# Out:
# dict_keys(['id', 'name', 'country', 'logo', 'flag', 'season', 'standings'])

# %%
df['response'][0]['league']['standings'][0][0].keys()
# Out:
# dict_keys(['rank', 'team', 'points', 'goalsDiff', 'group', 'form', 'status', 'description', 'all', 'home', 'away', 'update'])

# %%
df['response'][0]['league']['standings'][0][0]['update']
# Out:
# '2020-07-26T00:00:00+00:00'

# %%
while True:
    # main program
    while True:
        answer = str(input('Run again? (y/n): '))
        if answer in ('y', 'n'):
            break
        print("invalid input.")
    if answer == 'y':
        continue
    else:
        print("Goodbye")
        break
# Out:
# Run again? (y/n): n
# Goodbye

# %%
import requests

url = "https://livescore6.p.rapidapi.com/matches/v2/get-scoreboard"

querystring = {"Eid":"702093","Category":"soccer"}

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "livescore6.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print (type(response.json()))
print(response.json())
df = response.json()
# Out:
# <class 'dict'>
# ...

# %%
df
# Out:
# {'Eid': '702093',
#  'Pids': {'32': '2699489',
#   '1': '3901012',
#   '6': '34151847',
#   '8': '702093',
#   '12': 'SBTE_27476152',
#   '28': '1210119345',
#   '30': 'c6677013-214b-4459-81f0-68ec91c51394'},
#  'Sids': {'32': '18118',
#   '1': '879290',
#   '6': '65927',
#   '8': '10765',
#   '28': '1209617720',
#   '12': 'SBTC3_40253',
#   '30': '855adaf5-49f3-4887-b304-dfb8be78fdbb'},
#  'Media': {'32': [{'ageRestricted': 'false',
#     'articleId': '2022100113224853898',
#     'type': 'RESULT'}],
#   '12': [{'eventId': 'BT Sport 1',
#     'provider': 'ABELSON',
#     'allowedCountries': ['GB', 'IE'],
#     'type': 'TV_CHANNEL'},
#    {'eventId': 'Viaplay',
#     'provider': 'ABELSON',
#     'allowedCountries': ['NL'],
#     'type': 'TV_CHANNEL'}]},
#  'Tr1': '3',
#  'Tr2': '1',
#  'Trh1': '1',
#  'Trh2': '1',
#  'Tr1OR': '3',
#  'Tr2OR': '1',
#  'T1': [{'Nm': 'Arsenal',
#    'ID': '2773',
#    'Img': 'enet/9825.png',
#    'NewsTag': '/team/arsenal-2021020913320920836-97/',
# ...

# %%
df.keys()
# Out:
# dict_keys(['Eid', 'Pids', 'Sids', 'Media', 'Tr1', 'Tr2', 'Trh1', 'Trh2', 'Tr1OR', 'Tr2OR', 'T1', 'T2', 'Eps', 'Esid', 'Epr', 'Ecov', 'Ern', 'ErnInf', 'Ewt', 'Et', 'Esd', 'LuUT', 'Edf', 'Eact', 'EO', 'LuC', 'Ehid', 'Spid', 'Stg', 'Pid', 'Eloff', 'Incs-s'])

# %%
df['Pids']
# Out:
# {'32': '2699489',
#  '1': '3901012',
#  '6': '34151847',
#  '8': '702093',
#  '12': 'SBTE_27476152',
#  '28': '1210119345',
#  '30': 'c6677013-214b-4459-81f0-68ec91c51394'}

# %%
import requests

url = "https://livescore6.p.rapidapi.com/matches/v2/get-scoreboard"

querystring = {"Eid":"702093","Category":"soccer"}

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "livescore6.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print (type(response.json()))
print(response.json())
df = response.json()
# Out:
# <class 'dict'>
# ...

# %%
df.keys()
# Out:
# dict_keys(['Eid', 'Pids', 'Sids', 'Media', 'Tr1', 'Tr2', 'Trh1', 'Trh2', 'Tr1OR', 'Tr2OR', 'T1', 'T2', 'Eps', 'Esid', 'Epr', 'Ecov', 'Ern', 'ErnInf', 'Ewt', 'Et', 'Esd', 'LuUT', 'Edf', 'Eact', 'EO', 'LuC', 'Ehid', 'Spid', 'Stg', 'Pid', 'Eloff', 'Incs-s'])

# %%
df
# Out:
# {'Eid': '702093',
#  'Pids': {'32': '2699489',
#   '1': '3901012',
#   '6': '34151847',
#   '8': '702093',
#   '12': 'SBTE_27476152',
#   '28': '1210119345',
#   '30': 'c6677013-214b-4459-81f0-68ec91c51394'},
#  'Sids': {'32': '18118',
#   '1': '879290',
#   '6': '65927',
#   '8': '10765',
#   '28': '1209617720',
#   '12': 'SBTC3_40253',
#   '30': '855adaf5-49f3-4887-b304-dfb8be78fdbb'},
#  'Media': {'32': [{'ageRestricted': 'false',
#     'articleId': '2022100113224853898',
#     'type': 'RESULT'}],
#   '12': [{'eventId': 'BT Sport 1',
#     'provider': 'ABELSON',
#     'allowedCountries': ['GB', 'IE'],
#     'type': 'TV_CHANNEL'},
#    {'eventId': 'Viaplay',
#     'provider': 'ABELSON',
#     'allowedCountries': ['NL'],
#     'type': 'TV_CHANNEL'}]},
#  'Tr1': '3',
#  'Tr2': '1',
#  'Trh1': '1',
#  'Trh2': '1',
#  'Tr1OR': '3',
#  'Tr2OR': '1',
#  'T1': [{'Nm': 'Arsenal',
#    'ID': '2773',
#    'Img': 'enet/9825.png',
#    'NewsTag': '/team/arsenal-2021020913320920836-97/',
# ...

# %%
import requests

url = "https://football-betting-odds1.p.rapidapi.com/provider1/live/inplaying"

headers = {
	"X-RapidAPI-Key": "62a02ca5ccmsha68a5acf6c698d9p1ffc12jsnbe2b9a765139",
	"X-RapidAPI-Host": "football-betting-odds1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)

print(response.text)
